# %%
print("Hellozd")
# Out:
# Hello

# %% [markdown]
# Here’s a **clear, structured explanation of GANs (Generative Adversarial Networks)** — one of the most powerful generative models in AI 👇
#
# ***
#
# # ✅ 1. What is GAN?
#
# **GAN (Generative Adversarial Network)** is a **deep learning model used to generate new data** (images, text, etc.).
#
# 👉 Instead of predicting:
#
# ```
# GAN → CREATES new data
# ```
#
# 👉 Example:
#
# * Generate fake human faces
# * Create synthetic network traffic data
# * Generate logs/images
#
# 👉 GANs were introduced in **2014 by Ian Goodfellow** [\[https://us...s/original\]](https://us-prod.asyncgw.teams.microsoft.com/v1/objects/0-eus-d12-6c4f6126785cf38e5814a635b5259353/views/original)
#
# ***
#
# # ✅ 2. Core Idea (Very Important)
#
# 👉 “Two neural networks competing with each other”
#
# ```
# Generator vs Discriminator
# ```
#
# 👉 Like a game:
#
# | Network       | Role                 |
# | ------------- | -------------------- |
# | Generator     | Creates fake data    |
# | Discriminator | Detects real vs fake |
#
# ***
#
# # ✅ 3. Simple Intuition
#
# 👉 Think like this:
#
# * Generator = 🎨 Fake artist
# * Discriminator = 🕵️ Detector
#
# Process:
#
# ```
# Generator tries to fool discriminator
# Discriminator tries to catch generator
# ```
#
# 👉 Over time:
#
# * Generator becomes better at creating realistic data
# * Discriminator becomes better at detecting fake    [\[geeksforgeeks.org\]](https://www.geeksforgeeks.org/deep-learning/generative-adversarial-network-gan/)
#
# ***
#
# # ✅ 4. GAN Architecture
#
# ```
# Noise (random input) → Generator → Fake Data
#                                 ↓
# Real Data  -----------------> Discriminator → Real / Fake
# ```
#
# 👉 Two networks trained **together (adversarial training)** [\[https://us...s/original\]](https://us-prod.asyncgw.teams.microsoft.com/v1/objects/0-eus-d12-6c4f6126785cf38e5814a635b5259353/views/original)
#
# ***
#
# # ✅ 5. How GAN Works (Step-by-Step)
#
# ### Step 1: Generator creates fake data
#
# ```
# z (random noise) → G(z) → fake sample
# ```
#
# ***
#
# ### Step 2: Discriminator checks data
#
# * Input:
#   * Real data ✅
#   * Generated data ❌
#
# 👉 Output:
#
# ```
# Probability (real or fake)
# ```
#
# ***
#
# ### Step 3: Training loop
#
# 1. Train discriminator
#    * Learn real vs fake
#
# 2. Train generator
#    * Try to fool discriminator
#
# 3. Repeat
#
# 👉 Eventually:
#
# ```
# Fake data ≈ Real data ✅
# ```
#
# ***
#
# # ✅ 6. Loss Functions (Core Math Idea)
#
# 👉 GAN training is a **min-max game**:
#
# ### Discriminator wants:
#
# ```
# Maximize:
# log(D(real)) + log(1 - D(fake))
# ```
#
# ***
#
# ### Generator wants:
#
# ```
# Minimize:
# log(1 - D(fake))
# ```
#
# 👉 Or better:
#
# ```
# Maximize:
# log(D(fake))
# ```
#
# 👉 This creates competition between both networks [\[teachfloor.com\]](https://www.teachfloor.com/blog/generative-adversarial-network)
#
# ***
#
# # ✅ 7. Sample Python Code (Simplified GAN)
#
# ```python
# import torch
# import torch.nn as nn
#
# # Generator
# class Generator(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.model = nn.Sequential(
#             nn.Linear(100, 256),
#             nn.ReLU(),
#             nn.Linear(256, 784),
#             nn.Tanh()
#         )
#     def forward(self, z):
#         return self.model(z)
#
# # Discriminator
# class Discriminator(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.model = nn.Sequential(
#             nn.Linear(784, 256),
#             nn.ReLU(),
#             nn.Linear(256, 1),
#             nn.Sigmoid()
#         )
#     def forward(self, x):
#         return self.model(x)
# ```
#
# ***
#
# # ✅ 8. Sample Output
#
# 👉 After training (example):
#
# ```
# Generated Images:
# [handwritten digits-like images]
# ```
#
# 👉 Output = synthetic data (not classification)
#
# ***
#
# # ✅ 9. Why GANs Are Powerful
#
# ✅ Unique ability:
#
# * Generate realistic data
# * Learn distribution automatically
#
# 👉 Produces:
#
# * Human faces
# * Art
# * Synthetic datasets
#
# ***
#
# # ✅ 10. Real-World Use Cases
#
# ### 🔹 Image Generation
#
# * Fake human faces (e.g., AI portraits)
#
# ### 🔹 Data Augmentation
#
# * Create extra training data
#
# ### 🔹 Security / Simulation
#
# * Simulate attack traffic (VERY useful for your domain)
#
# ### 🔹 Deepfake / Video AI
#
# * Video synthesis
#
# ***
#
# # ✅ 11. Challenges (Important)
#
# GANs are powerful but hard:
#
# ❌ Training instability
# ❌ Mode collapse (same outputs repeatedly)
# ❌ Requires careful tuning
#
# ***
#
# # ✅ 12. GAN vs Other Models
#
# | Model         | Output               |
# | ------------- | -------------------- |
# | Logistic      | Probability          |
# | Decision Tree | Rules                |
# | Neural Net    | Prediction           |
# | CNN           | Image classification |
# | Transformer   | Text understanding   |
# | ✅ GAN         | Data generation ✅    |
#
# ***
#
# # ✅ 13. Key Summary
#
# * Two networks **compete (generator vs discriminator)**
# * Learns to **generate realistic data**
# * Uses **adversarial training**
# * Powerful but harder to train
#
# ***
#
# # ✅ 🔥 Big Picture (Final Understanding)
#
# ```
# Prediction Models → Logistic, Tree, XGBoost
# Pattern Models → Neural Nets, CNN
# Sequence Models → Transformers
# ✅ Generative Models → GANs (CREATE new data)
# ```
#
# ***
#
# ✅ **Important insight for YOU (network/cloud engineer):**
#
# GANs can be used for:
#
# * Generating synthetic network traffic for testing
# * Creating anomaly datasets
# * Simulating failures for RCA models
#
# ***
#
# ✅ If you want next, I can give:
# 👉 **Complete final comparison of ALL ML/DL models + when to use each in real production systems (very useful for interviews + your Azure work)**

# %%
# !pip install torch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: C:\Users\v-yaalam\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import torch
import torch.nn as nn

# Generator
class Generator(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(100, 256),
            nn.ReLU(),
            nn.Linear(256, 784),
            nn.Tanh()
        )
    def forward(self, z):
        return self.model(z)

# Discriminator
class Discriminator(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(784, 256),
            nn.ReLU(),
            nn.Linear(256, 1),
            nn.Sigmoid()
        )
    def forward(self, x):
        return self.model(x)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import torch
#       2 import torch.nn as nn
#       3
#       4 # Generator
#
# ModuleNotFoundError: No module named 'torch'
