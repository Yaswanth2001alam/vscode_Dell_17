# %% [markdown]
# https://docs.pytest.org/en/stable/getting-started.html

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
pip install -U pytest
# Out:
# ...
#   Using cached pytest-9.0.2-py3-none-any.whl.metadata (7.6 kB)
# ...
#   Using cached iniconfig-2.3.0-py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached pluggy-1.6.0-py3-none-any.whl.metadata (4.8 kB)
# ...
# Using cached pytest-9.0.2-py3-none-any.whl (374 kB)
# Using cached pluggy-1.6.0-py3-none-any.whl (20 kB)
# Using cached iniconfig-2.3.0-py3-none-any.whl (7.5 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━ 2/3 [pytest]  WARNING: The scripts py.test and pytest are installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pytest]
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pytest --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 pytest --version
#
# NameError: name 'pytest' is not defined

# %%
# !pytest --version
# Out:
# pytest 9.0.2

# %%
def func(x):
    return x + 1

# %%
def test_answer():
    assert func(3) == 5

# %% [markdown]
# https://github.com/ansible/pytest-ansible
#
#
# https://github.com/ansible/pytest-ansible
#
#
#
# ![image.png](attachment:image.png)

# %%
import pytest

# %%
import test_tmp_path

# !pytest -q test_tmp_path.py
# Out:
# F                                                                        [100%]
# =================================== FAILURES ===================================
# _______________________________ test_needsfiles ________________________________
#
# tmp_path = PosixPath('/tmp/pytest-of-codespace/pytest-8/test_needsfiles0')
#
#     def test_needsfiles(tmp_path):
#         print(tmp_path)
# >       assert 0
# E       assert 0
#
# test_tmp_path.py:5: AssertionError
# ----------------------------- Captured stdout call -----------------------------
# /tmp/pytest-of-codespace/pytest-8/test_needsfiles0
# =========================== short test summary info ============================
# FAILED test_tmp_path.py::test_needsfiles - assert 0
# 1 failed in 0.39s

# %%
import test_approx

# !pytest -q test_approx.py
# Out:
# .                                                                        [100%]
# 1 passed in 0.04s

# %%
import test_class_demo

# !pytest -q test_class_demo.py
# Out:
# .F                                                                       [100%]
# =================================== FAILURES ===================================
# ________________________ TestClassDemoInstance.test_two ________________________
#
# self = <test_class_demo.TestClassDemoInstance object at 0x7d30525566f0>
#
#     def test_two(self):
# >       assert self.value == 1
# E       assert 0 == 1
# E        +  where 0 = <test_class_demo.TestClassDemoInstance object at 0x7d30525566f0>.value
#
# test_class_demo.py:9: AssertionError
# =========================== short test summary info ============================
# FAILED test_class_demo.py::TestClassDemoInstance::test_two - assert 0 == 1
# 1 failed, 1 passed in 0.26s

# %%
import test_class

# !pytest -q test_class.py
# Out:
# .F                                                                       [100%]
# =================================== FAILURES ===================================
# ______________________________ TestClass.test_two ______________________________
#
# self = <test_class.TestClass object at 0x78a78d6ea690>
#
#     def test_two(self):
#         x = "hello"
# >       assert hasattr(x, "check")
# E       AssertionError: assert False
# E        +  where False = hasattr('hello', 'check')
#
# test_class.py:8: AssertionError
# =========================== short test summary info ============================
# FAILED test_class.py::TestClass::test_two - AssertionError: assert False
# 1 failed, 1 passed in 0.33s

# %%
import test_sample

# !pytest -q test_sample.py
# Out:
# F                                                                        [100%]
# =================================== FAILURES ===================================
# _________________________________ test_answer __________________________________
#
#     def test_answer():
# >       assert func(3) == 5
# E       assert 4 == 5
# E        +  where 4 = func(3)
#
# test_sample.py:7: AssertionError
# =========================== short test summary info ============================
# FAILED test_sample.py::test_answer - assert 4 == 5
# 1 failed in 0.27s

# %%
import test_sysexit

# !pytest -q test_sysexit.py
# Out:
# .                                                                        [100%]
# 1 passed in 0.03s

# %%
import test_tmp_path

# !pytest -q test_tmp_path.py
# Out:
# F                                                                        [100%]
# =================================== FAILURES ===================================
# _______________________________ test_needsfiles ________________________________
#
# tmp_path = PosixPath('/tmp/pytest-of-codespace/pytest-9/test_needsfiles0')
#
#     def test_needsfiles(tmp_path):
#         print(tmp_path)
# >       assert 0
# E       assert 0
#
# test_tmp_path.py:5: AssertionError
# ----------------------------- Captured stdout call -----------------------------
# /tmp/pytest-of-codespace/pytest-9/test_needsfiles0
# =========================== short test summary info ============================
# FAILED test_tmp_path.py::test_needsfiles - assert 0
# 1 failed in 0.16s

# %%
import test_tmp_path1

# !pytest -q test_tmp_path1.py
# Out:
# .                                                                        [100%]
# 1 passed in 0.04s

# %% [markdown]
# https://docs.pytest.org/en/stable/how-to/usage.html
#
#
# ![image.png](attachment:image.png)

# %%
import test_class

# %%
# !pytest test_class.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.1, pytest-9.0.2, pluggy-1.6.0
# rootdir: /workspaces/v-yaalam_MSFT_repo/pytest
# plugins: anyio-4.11.0
# collected 2 items
#
# test_class.py .F                                                         [100%]
#
# =================================== FAILURES ===================================
# ______________________________ TestClass.test_two ______________________________
#
# self = <test_class.TestClass object at 0x73a8babaf2f0>
#
#     def test_two(self):
#         x = "hello"
# >       assert hasattr(x, "check")
# E       AssertionError: assert False
# E        +  where False = hasattr('hello', 'check')
#
# test_class.py:8: AssertionError
# =========================== short test summary info ============================
# FAILED test_class.py::TestClass::test_two - AssertionError: assert False
# ...

# %%
import test_tmp_path1

# !pytest -k test_tmp_path1.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.1, pytest-9.0.2, pluggy-1.6.0
# rootdir: /workspaces/v-yaalam_MSFT_repo/pytest
# plugins: anyio-4.11.0
# collected 9 items / 8 deselected / 1 selected
#
# test_tmp_path1.py .                                                      [100%]
#
# ======================= 1 passed, 8 deselected in 0.07s ========================

# %%
import test_tmp_path

# !pytest -k test_tmp_path.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.1, pytest-9.0.2, pluggy-1.6.0
# rootdir: /workspaces/v-yaalam_MSFT_repo/pytest
# plugins: anyio-4.11.0
# collected 9 items / 8 deselected / 1 selected
#
# test_tmp_path.py F                                                       [100%]
#
# =================================== FAILURES ===================================
# _______________________________ test_needsfiles ________________________________
#
# tmp_path = PosixPath('/tmp/pytest-of-codespace/pytest-12/test_needsfiles0')
#
#     def test_needsfiles(tmp_path):
#         print(tmp_path)
# >       assert 0
# E       assert 0
#
# test_tmp_path.py:5: AssertionError
# ----------------------------- Captured stdout call -----------------------------
# /tmp/pytest-of-codespace/pytest-12/test_needsfiles0
# =========================== short test summary info ============================
# ...

# %%
import test_tmp_path

# !pytest -k -q test_tmp_path.py
# Out:
# ERROR: usage: pytest [options] [file_or_dir] [file_or_dir] [...]
# pytest: error: argument -k: expected one argument

# %%
import test_tmp_path

# !pytest -q test_tmp_path.py
# Out:
# F                                                                        [100%]
# =================================== FAILURES ===================================
# _______________________________ test_needsfiles ________________________________
#
# tmp_path = PosixPath('/tmp/pytest-of-codespace/pytest-13/test_needsfiles0')
#
#     def test_needsfiles(tmp_path):
#         print(tmp_path)
# >       assert 0
# E       assert 0
#
# test_tmp_path.py:5: AssertionError
# ----------------------------- Captured stdout call -----------------------------
# /tmp/pytest-of-codespace/pytest-13/test_needsfiles0
# =========================== short test summary info ============================
# FAILED test_tmp_path.py::test_needsfiles - assert 0
# 1 failed in 0.20s

# %%
import test_tmp_path

# !pytest -q -k test_tmp_path.py
# Out:
# F                                                                        [100%]
# =================================== FAILURES ===================================
# _______________________________ test_needsfiles ________________________________
#
# tmp_path = PosixPath('/tmp/pytest-of-codespace/pytest-14/test_needsfiles0')
#
#     def test_needsfiles(tmp_path):
#         print(tmp_path)
# >       assert 0
# E       assert 0
#
# test_tmp_path.py:5: AssertionError
# ----------------------------- Captured stdout call -----------------------------
# /tmp/pytest-of-codespace/pytest-14/test_needsfiles0
# =========================== short test summary info ============================
# FAILED test_tmp_path.py::test_needsfiles - assert 0
# 1 failed, 8 deselected in 0.34s

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pytest

# %%
# !pytest --version
# Out:
# pytest 9.0.2

# %%
# !pytest --fixtures
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.1, pytest-9.0.2, pluggy-1.6.0
# rootdir: /workspaces/v-yaalam_MSFT_repo/pytest
# plugins: anyio-4.11.0
# collected 9 items
# cache -- .../_pytest/cacheprovider.py:566
#     Return a cache object that can persist state between testing sessions.
#
# capsys -- .../_pytest/capture.py:1000
#     Enable text capturing of writes to ``sys.stdout`` and ``sys.stderr``.
#
# capteesys -- .../_pytest/capture.py:1028
#     Enable simultaneous text capturing and pass-through of writes
#     to ``sys.stdout`` and ``sys.stderr`` as defined by ``--capture=``.
#
# capsysbinary -- .../_pytest/capture.py:1063
#     Enable bytes capturing of writes to ``sys.stdout`` and ``sys.stderr``.
#
# capfd -- .../_pytest/capture.py:1091
#     Enable text capturing of writes to file descriptors ``1`` and ``2``.
#
# capfdbinary -- .../_pytest/capture.py:1119
# ...

# %%
# !pytest -h | --help
# Out:
# /bin/bash: line 1: --help: command not found

# %%
import myinvoke

# !python myinvoke.py
# Out:
# ..F.FF.F.                                                                [100%]*** test run reporting finishing
#
# =================================== FAILURES ===================================
# ______________________________ TestClass.test_two ______________________________
#
# self = <test_class.TestClass object at 0x718683226c30>
#
#     def test_two(self):
#         x = "hello"
# >       assert hasattr(x, "check")
# E       AssertionError: assert False
# E        +  where False = hasattr('hello', 'check')
#
# test_class.py:8: AssertionError
# ________________________ TestClassDemoInstance.test_two ________________________
#
# self = <test_class_demo.TestClassDemoInstance object at 0x7186832272c0>
#
#     def test_two(self):
# >       assert self.value == 1
# E       assert 0 == 1
# E        +  where 0 = <test_class_demo.TestClassDemoInstance object at 0x7186832272c0>.value
#
# test_class_demo.py:9: AssertionError
# ...

# %% [markdown]
# https://docs.pytest.org/en/stable/how-to/assert.html
#
# How to write and report assertions in tests
#
#
# ![image.png](attachment:image.png)

# %%
import test_assert1

# %%
# !pytest test_assert1.py
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.13.12, pytest-9.0.2, pluggy-1.6.0
# rootdir: c:\Users\v-yaalam\Downloads\vscode_Dell_17\pytest
# collected 1 item
#
# test_assert1.py F                                                        [100%]
#
# ================================== FAILURES ===================================
# ________________________________ test_function ________________________________
#
#     def test_function():
# >       assert f() == 4
# E       assert 3 == 4
# E        +  where 3 = f()
#
# test_assert1.py:6: AssertionError
# =========================== short test summary info ===========================
# FAILED test_assert1.py::test_function - assert 3 == 4
# ============================== 1 failed in 0.12s ==============================

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://docs.pytest.org/en/stable/how-to/assert.html
#
# ![![image.png](attachment:image.png)](attachment:image.png)

# %%
import test_assert2

# %%
# !pytest test_assert2.py
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.13.12, pytest-9.0.2, pluggy-1.6.0
# rootdir: c:\Users\v-yaalam\Downloads\vscode_Dell_17\pytest
# collected 1 item
#
# test_assert2.py F                                                        [100%]
#
# ================================== FAILURES ===================================
# _____________________________ test_set_comparison _____________________________
#
#     def test_set_comparison():
#         set1 = set("1308")
#         set2 = set("8035")
# >       assert set1 == set2
# E       AssertionError: assert {'0', '1', '3', '8'} == {'0', '3', '5', '8'}
# E
# E         Extra items in the left set:
# E         '1'
# E         Extra items in the right set:
# E         '5'
# E         Use -v to get more diff
#
# test_assert2.py:5: AssertionError
# =========================== short test summary info ===========================
# ...
