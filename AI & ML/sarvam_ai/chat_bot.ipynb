# %%
"""
Multi-turn chatbot with memory, running in your terminal.
Keeps conversation context across turns until you type 'exit'.
"""
import os
from dotenv import load_dotenv
from sarvamai import SarvamAI

load_dotenv()
client = SarvamAI(api_subscription_key=os.getenv("SARVAM_API_KEY"))

history = [{"role": "system", "content": "You are a helpful, friendly assistant."}]

print("Chatbot ready. Type 'exit' to quit.\n")

while True:
    user_input = input("You: ").strip()
    if user_input.lower() in ("exit", "quit"):
        print("Goodbye!")

        
        break
    if not user_input:
        continue

    history.append({"role": "user", "content": user_input})

    try:
        response = client.chat.completions(
            model="sarvam-105b",
            messages=history,
            temperature=0.7,
        )
        reply = response.choices[0].message.content
        history.append({"role": "assistant", "content": reply})
        print(f"Bot: {reply}\n")
    except Exception as e:
        print(f"Error: {e}\n")
# Out:
# Chatbot ready. Type 'exit' to quit.
#
# Bot: Of course! BGP is a fascinating and foundational protocol in networking. Let's break it down, from a simple analogy to the details that matter.
#
# ---
#
# ### The Simple Analogy: The Global Postal Service
#
# Imagine BGP is the protocol that the entire world's postal service uses.
#
# *   **Your Router is your local post office.** It has to figure out how to send a package.
# *   **Other networks are other countries.**
# *   **BGP is the global agreement and set of rules** that allows a post office in one country to send mail to a post office in another country.
#
# Your local post office doesn't need to know the exact street address of every house in the world. It just needs to know:
# 1.  What other post offices can I send packages to? **(The "Peer")**
# 2.  How do I get to them? **(The "Path")**
# 3.  Who are my preferred partners to send with? **(The "Policy")**
#
# This is precisely what BGP does for the internet.
#
# ---
#
# ### What is BGP? The Header Answer
#
# **BGP (Border Gateway Protocol)** is the routing protocol of the internet.
#
# Its primary job is to exchange **reachability information** (i.e., which network prefixes can be reached) with other **Autonomous Systems (ASes)** on the internet.
#
# Let's unpack that:
#
# *   **Routing Protocol:** A set of rules that allows routers to automatically share and update information about network paths.
# *   **Autonomous System (AS):** A collection of connected IP networks managed by one organization (like an ISP, a university, or a large company). An AS acts as a single entity for external routing.
#
# So, instead of routers inside a single network talking to each other (like OSPF or EIGRP), **BGP allows the *edges* of different networks (the ASes) to talk.**
#
# ---
#
# ### How BGP Works: The High-Level
#
# BGP is fundamentally different from interior routing protocols because it's a **path vector protocol**, not a distance-vector protocol.
#
# *   **Distance-Vector (like old RIP):** "The best route to 192.168.1.0 is through router 2, and it's 3 'hops' away."
# *   **Path-Vector (BGP):** "To get to 203.0.113.
#
# Bot: Excellent question! BGP attributes are the very heart and soul of what makes BGP so powerful. Think of them as the **metadata or "tags"** that BGP puts on each route, allowing for incredibly granular control over how traffic flows across the internet.
#
# Without attributes, all routes would be treated equally, and BGP would just be a naive lookup table.
#
# There are two main categories of attributes:
#
# 1.  **Well-Known Attributes:** These are mandatory, and every BGP implementation must understand them. They can be **transitive** (passed along to other peers) or **non-transitive** (can be stripped).
# 2.  **Optional Attributes:** These are not mandatory and are used for specific policy-based interactions.
#
# Let's dive into the most important ones, starting with the core set that most engineers use daily.
#
# ---
#
# ### The "Big Four" Core Attributes
#
# These are the attributes you will set and manipulate most often.
#
# #### 1. AS_PATH
# This is the single most important attribute in BGP.
#
# *   **What it is:** A list of all the Autonomous System (AS) numbers a route has passed through to get to you.
#
# Bot: None
#
# Bot: None
#
# Goodbye!
