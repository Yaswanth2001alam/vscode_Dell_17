# %% [markdown]
# Python Basics Part 4 🐍🔥
#
# File Handling & Exception Handling
#
# Real-world applications need to store and manage data. That’s where file handling becomes important. 💻
#
# In this part, you’ll learn:
# ✅ Read Files
# ✅ Write Files
# ✅ Append Data
# ✅ CSV Files
# ✅ Exception Handling
# ✅ try-except
#
# 🧠 1. What is File Handling?
# File handling allows Python to:
# ✔️ Read data from files
# ✔️ Write data into files
# ✔️ Store information permanently
#
# 📂 2. Opening a File
# Use open() to work with files.
#
# Example:
# file = open("data.txt", "r")
#
# 📌 "r" means read mode.
#
# 📖 3. Reading a File
#
# 📌 Read Entire File
# Example:
# file = open("data.txt", "r")
# content = file.read()
# print(content)
# file.close()
#
# 📄 4. Read Line by Line
# Example:
# file = open("data.txt", "r")
# for line in file:
#     print(line)
# file.close()
#
# ✍️ 5. Writing to a File
# Use "w" mode to write data.
#
# Example:
# file = open("notes.txt", "w")
# file.write("Python File Handling")
# file.close()
#
# ⚠️ "w" overwrites existing data.
#
# ➕ 6. Appending Data
# Use "a" mode to add data without deleting old content.
#
# Example:
# file = open("notes.txt", "a")
# file.write("\nNew Line Added")
# file.close()
#
# 🔒 7. Using with Statement
# Best way to handle files.
#
# Example:
# with open("data.txt", "r") as file:
#     content = file.read()
#     print(content)
#
# ✔️ Automatically closes the file
# ✔️ Cleaner and safer code
#
# 📊 8. Working with CSV Files
# CSV files are used for tabular data.
#
# Example:
# import csv
# with open("data.csv", "r") as file:
#     reader = csv.reader(file)
#     for row in reader:
#         print(row)
#
# ⚠️ 9. What is Exception Handling?
# Errors can crash programs.
# Exception handling prevents that.
#
# 🛡️ 10. try-except Block
# Example:
# try:
#     num = int(input("Enter Number: "))
#     print(num)
# except:
#     print("Invalid Input")
#
# 📌 If the user enters text instead of number, the program won’t crash.
#
# ⚡ 11. Handling Specific Errors
#
# Example:
# try:
#     result = 10 / 0
# except ZeroDivisionError:
#     print("Cannot divide by zero")
#
# 🔄 12. finally Block
# finally always runs whether error occurs or not.
#
# Example:
# try:
#     print("Start")
# except:
#     print("Error")
# finally:
#     print("Finished")
#
# 🛠️ Beginner Practice Programs
# ✅ Notes App
# ✅ Student Record System
# ✅ Expense Tracker
# ✅ CSV Reader
# ✅ Login System with File Storage
#
# 🔥 Common Beginner Mistakes
# ❌ Forgetting to close files
# ❌ Using wrong file mode
# ❌ Ignoring exceptions
# ❌ Overwriting important data accidentally
#
# 💡 Pro Tip
# ✔️ Always use with open()
# ✔️ Handle errors properly
# ✔️ Save user data using files
#
# File handling is heavily used in:
# 📊 Data Analysis
# 🌐 Web Apps
# 🤖 Automation
# 📱 Applications

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# 📂 2. Opening a File
# Use open() to work with files.
#
# Example:
# file = open("data.txt", "r")
#
# 📌 "r" means read mode.

# %%
file = open("network_data.txt", "r")

# %% [markdown]
# 📖 3. Reading a File
#
# 📌 Read Entire File
# Example:
# file = open("data.txt", "r")
# content = file.read()
# print(content)
# file.close()

# %%
file = open("network_data.txt" , "r")
content = file.read()
print(content)
file.close()
# Out:
# NETWORK ENGINEERING PRACTICE FILE
#
# # Device Inventory
# Router1, 10.1.1.1, Cisco
# Router2, 10.1.1.2, Juniper
# Switch1, 10.2.1.1, Arista
# Firewall1, 10.3.1.1, PaloAlto
#
# # Interface Status
# Gig0/0, up, 1Gbps
# Gig0/1, down, 1Gbps
# Gig0/2, up, 10Gbps
#
# # Routing Table
# O 10.10.10.0/24 via 10.1.1.1
# B 20.20.20.0/24 via 10.1.1.2
# S 30.30.30.0/24 via 10.1.1.3
#
# # Logs
# INFO: BGP session established with 10.1.1.2
# WARNING: Interface Gig0/1 is down
# ERROR: Packet drop detected on Gig0/2

# %%
file = open("network_data.txt" , "+a")
content = file.read()
print(content)
file.close()

# %%
file = open("network_data.txt" , "+rb")
content = file.read()
print(content)
file.close()
# Out:
# b'\nNETWORK ENGINEERING PRACTICE FILE\n\n# Device Inventory\nRouter1, 10.1.1.1, Cisco\nRouter2, 10.1.1.2, Juniper\nSwitch1, 10.2.1.1, Arista\nFirewall1, 10.3.1.1, PaloAlto\n\n# Interface Status\nGig0/0, up, 1Gbps\nGig0/1, down, 1Gbps\nGig0/2, up, 10Gbps\n\n# Routing Table\nO 10.10.10.0/24 via 10.1.1.1\nB 20.20.20.0/24 via 10.1.1.2\nS 30.30.30.0/24 via 10.1.1.3\n\n# Logs\nINFO: BGP session established with 10.1.1.2\nWARNING: Interface Gig0/1 is down\nERROR: Packet drop detected on Gig0/2\n'

# %%
file = open("network_data.txt" , "+rt")
content = file.read()
print(content)
file.close()
# Out:
# NETWORK ENGINEERING PRACTICE FILE
#
# # Device Inventory
# Router1, 10.1.1.1, Cisco
# Router2, 10.1.1.2, Juniper
# Switch1, 10.2.1.1, Arista
# Firewall1, 10.3.1.1, PaloAlto
#
# # Interface Status
# Gig0/0, up, 1Gbps
# Gig0/1, down, 1Gbps
# Gig0/2, up, 10Gbps
#
# # Routing Table
# O 10.10.10.0/24 via 10.1.1.1
# B 20.20.20.0/24 via 10.1.1.2
# S 30.30.30.0/24 via 10.1.1.3
#
# # Logs
# INFO: BGP session established with 10.1.1.2
# WARNING: Interface Gig0/1 is down
# ERROR: Packet drop detected on Gig0/2

# %%
file = open("network_data.txt" , "+tr")
content = file.read()
print(content)
file.close()
# Out:
# NETWORK ENGINEERING PRACTICE FILE
#
# # Device Inventory
# Router1, 10.1.1.1, Cisco
# Router2, 10.1.1.2, Juniper
# Switch1, 10.2.1.1, Arista
# Firewall1, 10.3.1.1, PaloAlto
#
# # Interface Status
# Gig0/0, up, 1Gbps
# Gig0/1, down, 1Gbps
# Gig0/2, up, 10Gbps
#
# # Routing Table
# O 10.10.10.0/24 via 10.1.1.1
# B 20.20.20.0/24 via 10.1.1.2
# S 30.30.30.0/24 via 10.1.1.3
#
# # Logs
# INFO: BGP session established with 10.1.1.2
# WARNING: Interface Gig0/1 is down
# ERROR: Packet drop detected on Gig0/2

# %% [markdown]
# 📄 4. Read Line by Line
# Example:
# file = open("data.txt", "r")
# for line in file:
#     print(line)
# file.close()

# %%
file = open("network_data.txt" , "r")

for line in file:
    print(line)
file.close()
# Out:
# NETWORK ENGINEERING PRACTICE FILE
#
#
#
# # Device Inventory
#
# Router1, 10.1.1.1, Cisco
#
# Router2, 10.1.1.2, Juniper
#
# Switch1, 10.2.1.1, Arista
#
# Firewall1, 10.3.1.1, PaloAlto
#
#
#
# # Interface Status
#
# Gig0/0, up, 1Gbps
#
# Gig0/1, down, 1Gbps
#
# Gig0/2, up, 10Gbps
#
#
#
# # Routing Table
#
# O 10.10.10.0/24 via 10.1.1.1
#
# B 20.20.20.0/24 via 10.1.1.2
#
# S 30.30.30.0/24 via 10.1.1.3
#
#
#
# # Logs
#
# INFO: BGP session established with 10.1.1.2
#
# WARNING: Interface Gig0/1 is down
#
# ERROR: Packet drop detected on Gig0/2

# %% [markdown]
# ✍️ 5. Writing to a File
# Use "w" mode to write data.
#
# Example:
# file = open("notes.txt", "w")
# file.write("Python File Handling")
# file.close()
#
# ⚠️ "w" overwrites existing data.

# %%
file = open("network_data.1.txt", "w")
file.write("python file handling was modified by yaswanth for testing and learning purposes only")
file = open("network_data.1.txt", "r")
content2 = file.read()
print(content2)
file.close()
# Out:
# python file handling was modified by yaswanth for testing and learning purposes only

# %%
file = open("network_data.1.txt", "w")
file.write("Yaswanth is learning python and network automation with the vscode")
file = open("network_data.1.txt", "r")
content2 = file.read()
print(content2)
file.close()
# Out:
# Yaswanth is learning python and network automation with the vscode

# %% [markdown]
# ➕ 6. Appending Data
# Use "a" mode to add data without deleting old content.
#
# Example:
#
# file = open("notes.txt", "a")
#
# file.write("\nNew Line Added")
#
# file.close()

# %%
file4 = open("network_data.2..txt" , "a")
file4.write("Yaswanth added new line to the file to see where the data appends to the File")

file4 = open("network_data.2..txt" , "r")
content3 = file4.read()
print(content3)
file.close()
# Out:
# NETWORK ENGINEERING PRACTICE FILE
#
# # Device Inventory
# Router1, 10.1.1.1, Cisco
# Router2, 10.1.1.2, Juniper
# Switch1, 10.2.1.1, Arista
# Firewall1, 10.3.1.1, PaloAlto
#
# # Interface Status
# Gig0/0, up, 1Gbps
# Gig0/1, down, 1Gbps
# Gig0/2, up, 10Gbps
#
# # Routing Table
# O 10.10.10.0/24 via 10.1.1.1
# B 20.20.20.0/24 via 10.1.1.2
# S 30.30.30.0/24 via 10.1.1.3
#
# # Logs
# INFO: BGP session established with 10.1.1.2
# WARNING: Interface Gig0/1 is down
# ERROR: Packet drop detected on Gig0/2
# n Yaswanth added new line to the file to see where the data appends to the Filen Yaswanth added new line to the file to see where the data appends to the FileYaswanth added new line to the file to see where the data appends to the File

# %%
file4 = open("network_data.2..txt" , "a")
file4.write("Yaswanth added new line to the file to see where the data appends to the File/n")

file4 = open("network_data.2..txt" , "r")
content3 = file4.read()
print(content3)
file.close()
# Out:
# NETWORK ENGINEERING PRACTICE FILE
#
# # Device Inventory
# Router1, 10.1.1.1, Cisco
# Router2, 10.1.1.2, Juniper
# Switch1, 10.2.1.1, Arista
# Firewall1, 10.3.1.1, PaloAlto
#
# # Interface Status
# Gig0/0, up, 1Gbps
# Gig0/1, down, 1Gbps
# Gig0/2, up, 10Gbps
#
# # Routing Table
# O 10.10.10.0/24 via 10.1.1.1
# B 20.20.20.0/24 via 10.1.1.2
# S 30.30.30.0/24 via 10.1.1.3
#
# # Logs
# INFO: BGP session established with 10.1.1.2
# WARNING: Interface Gig0/1 is down
# ERROR: Packet drop detected on Gig0/2
# n Yaswanth added new line to the file to see where the data appends to the Filen Yaswanth added new line to the file to see where the data appends to the FileYaswanth added new line to the file to see where the data appends to the FileYaswanth added new line to the file to see where the data appends to the File/n

# %% [markdown]
# 🔒 7. Using with Statement
# Best way to handle files.
#
# Example:
# with open("data.txt", "r") as file:
#     content = file.read()
#     print(content)
#
# ✔️ Automatically closes the file
# ✔️ Cleaner and safer code
#
# ![image.png](attachment:image.png)

# %%
with open("network_data.txt", "r") as file:
    content6 = file.read()
    print(content6)
# Out:
# NETWORK ENGINEERING PRACTICE FILE
#
# # Device Inventory
# Router1, 10.1.1.1, Cisco
# Router2, 10.1.1.2, Juniper
# Switch1, 10.2.1.1, Arista
# Firewall1, 10.3.1.1, PaloAlto
#
# # Interface Status
# Gig0/0, up, 1Gbps
# Gig0/1, down, 1Gbps
# Gig0/2, up, 10Gbps
#
# # Routing Table
# O 10.10.10.0/24 via 10.1.1.1
# B 20.20.20.0/24 via 10.1.1.2
# S 30.30.30.0/24 via 10.1.1.3
#
# # Logs
# INFO: BGP session established with 10.1.1.2
# WARNING: Interface Gig0/1 is down
# ERROR: Packet drop detected on Gig0/2

# %% [markdown]
# 📊 8. Working with CSV Files
# CSV files are used for tabular data.
#
# Example:
# import csv
# with open("data.csv", "r") as file:
#     reader = csv.reader(file)
#     for row in reader:
#         print(row)
#
# ⚠️ 9. What is Exception Handling?
# Errors can crash programs.
# Exception handling prevents that.
#
# ![image.png](attachment:image.png)

# %%
# !pip install csv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement csv (from versions: none)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: C:\Users\v-yaalam\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for csv

# %%
import csv
with open("network_devices.csv", "r") as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Device Name', 'IP Address', 'Vendor', 'Status', 'Location']
# ['Router1', '10.1.1.1', 'Cisco', 'Up', 'DC1']
# ['Router2', '10.1.1.2', 'Juniper', 'Down', 'DC2']
# ['Switch1', '10.2.1.1', 'Arista', 'Up', 'DC1']
# ['Firewall1', '10.3.1.1', 'PaloAlto', 'Up', 'DC3']
# ['Router3', '10.1.1.3', 'Cisco', 'Down', 'DC2']

# %% [markdown]
# Great — this is exactly the right way to learn 👍 (hands-on + domain context).
#
# I’ve created a **network engineering practice file** for you:
#
# 👉 [Download network\_data.txt](https://us-prod.asyncgw.teams.microsoft.com/v1/objects/0-eus-d8-9369ee068a391f5f4d77e2db675c83b4/views/original/network_data.txt)
#
# ***
#
# # 🔥 How to Practice (Network Engineer Focus)
#
# Use this file to test **ALL file handling + exception handling concepts**.
#
# ***
#
# ## 🧪 1. Read Entire File
#
# ```python
# with open("network_data.txt", "r") as f:
#     data = f.read()
#     print(data)
# ```
#
# ***
#
# ## 🧪 2. Read Line-by-Line (log-style parsing)
#
# ```python
# with open("network_data.txt", "r") as f:
#     for line in f:
#         print(line.strip())
# ```
#
# ***
#
# ## 🧪 3. Extract Only Device Inventory
#
# ```python
# with open("network_data.txt", "r") as f:
#     for line in f:
#         if "Router" in line or "Switch" in line or "Firewall" in line:
#             name, ip, vendor = line.strip().split(", ")
#             print(f"Device: {name}, IP: {ip}, Vendor: {vendor}")
# ```
#
# ***
#
# ## 🧪 4. Detect Interface Issues (Real-world use ✅)
#
# ```python
# with open("network_data.txt", "r") as f:
#     for line in f:
#         if "down" in line:
#             print("ALERT:", line.strip())
# ```
#
# 👉 Matches your real work (interface down RCA)
#
# ***
#
# ## 🧪 5. Extract Routing Table
#
# ```python
# with open("network_data.txt", "r") as f:
#     for line in f:
#         if line.startswith(("O", "B", "S")):
#             print("Route:", line.strip())
# ```
#
# ***
#
# ## 🧪 6. Log Monitoring (very important for you ⚡)
#
# ```python
# with open("network_data.txt", "r") as f:
#     for line in f:
#         if "ERROR" in line:
#             print("CRITICAL:", line.strip())
# ```
#
# ***
#
# # ⚠️ Exception Handling Practice
#
# ## 🧪 7. Handle File Not Found
#
# ```python
# try:
#     with open("network_data_missing.txt", "r") as f:
#         print(f.read())
# except FileNotFoundError:
#     print("File not found - check path")
# ```
#
# ***
#
# ## 🧪 8. Handle Parsing Errors (very realistic case)
#
# ```python
# try:
#     with open("network_data.txt", "r") as f:
#         for line in f:
#             name, ip, vendor = line.strip().split(", ")
# except ValueError:
#     print("Line format mismatch - skipping invalid entries")
# ```
#
# ***
#
# ## 🧪 9. Combined Real Scenario (Production-like ✅)
#
# ```python
# try:
#     with open("network_data.txt", "r") as f:
#         for line in f:
#             if "ERROR" in line:
#                 print("🚨 Network Issue:", line.strip())
# except FileNotFoundError:
#     print("Log file missing")
# finally:
#     print("Log check completed")
# ```
#
# ***
#
# # 🚀 Advanced Practice (Highly Recommended for You)
#
# Based on your network + automation work:
#
# ***
#
# ## ✅ 1. Build a "Mini NOC Tool"
#
# * Read file
# * Count:
#   * Number of devices
#   * Number of down interfaces
#   * Number of errors
#
# ```python
# devices = 0
# errors = 0
#
# with open("network_data.txt", "r") as f:
#     for line in f:
#         if "Router" in line or "Switch" in line:
#             devices += 1
#         if "ERROR" in line:
#             errors += 1
#
# print("Devices:", devices)
# print("Errors:", errors)
# ```
#
# ***
#
# ## ✅ 2. Append Logs (simulate monitoring)
#
# ```python
# with open("network_data.txt", "a") as f:
#     f.write("\nERROR: BGP flapping detected on Router1")
# ```
#
# ***
#
# ## ✅ 3. Convert to CSV (automation use-case)
#
# ```python
# import csv
#
# with open("devices.csv", "w", newline="") as f:
#     writer = csv.writer(f)
#     writer.writerow(["Name", "IP", "Vendor"])
#
#     with open("network_data.txt", "r") as file:
#         for line in file:
#             if "," in line:
#                 writer.writerow(line.strip().split(", "))
# ```
#
# ***
#
# # 🧠 What You’re Actually Learning (Important)
#
# This maps directly to your real job:
#
# | Concept            | Real Use Case                       |
# | ------------------ | ----------------------------------- |
# | File Read          | Parsing device configs / logs       |
# | Append             | Writing automation logs             |
# | CSV                | Inventory export / reports          |
# | Exception Handling | Prevent script crashes in pipelines |
# | Filtering lines    | RCA / troubleshooting syslogs       |
#
# ***
#
# # 🔥 Next Level (If you want)
#
# I can help you build:
#
# ✅ Log analyzer tool (detect BGP flaps, interface drops)
# ✅ Network inventory parser (multi-vendor)
# ✅ Automation script with error-safe logging
# ✅ CLI output parser (like `show bgp summary`)
#
# ***
#
# 👉 Just tell me: *“build me a real network log analyzer in Python”* and I’ll create it end-to-end for you.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open("network_data.txt", "r") as f:
    data = f.read()
    print(data)
# Out:
# NETWORK ENGINEERING PRACTICE FILE
#
# # Device Inventory
# Router1, 10.1.1.1, Cisco
# Router2, 10.1.1.2, Juniper
# Switch1, 10.2.1.1, Arista
# Firewall1, 10.3.1.1, PaloAlto
#
# # Interface Status
# Gig0/0, up, 1Gbps
# Gig0/1, down, 1Gbps
# Gig0/2, up, 10Gbps
#
# # Routing Table
# O 10.10.10.0/24 via 10.1.1.1
# B 20.20.20.0/24 via 10.1.1.2
# S 30.30.30.0/24 via 10.1.1.3
#
# # Logs
# INFO: BGP session established with 10.1.1.2
# WARNING: Interface Gig0/1 is down
# ERROR: Packet drop detected on Gig0/2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open("network_data.txt", "r") as f:
    for line in f:
        print(line.strip())
# Out:
# NETWORK ENGINEERING PRACTICE FILE
#
# # Device Inventory
# Router1, 10.1.1.1, Cisco
# Router2, 10.1.1.2, Juniper
# Switch1, 10.2.1.1, Arista
# Firewall1, 10.3.1.1, PaloAlto
#
# # Interface Status
# Gig0/0, up, 1Gbps
# Gig0/1, down, 1Gbps
# Gig0/2, up, 10Gbps
#
# # Routing Table
# O 10.10.10.0/24 via 10.1.1.1
# B 20.20.20.0/24 via 10.1.1.2
# S 30.30.30.0/24 via 10.1.1.3
#
# # Logs
# INFO: BGP session established with 10.1.1.2
# WARNING: Interface Gig0/1 is down
# ERROR: Packet drop detected on Gig0/2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open("network_data.txt", "r") as f:
    for line in f:
        if "Router" in line or "Switch" in line or "Firewall" in line:
            name, ip, vendor = line.strip().split(", ")
            print(f"Device: {name}, IP: {ip}, Vendor: {vendor}")
# Out:
# Device: Router1, IP: 10.1.1.1, Vendor: Cisco
# Device: Router2, IP: 10.1.1.2, Vendor: Juniper
# Device: Switch1, IP: 10.2.1.1, Vendor: Arista
# Device: Firewall1, IP: 10.3.1.1, Vendor: PaloAlto

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open("network_data.txt", "r") as f:
    for line in f:
        if "down" in line:
            print("ALERT:", line.strip())
# Out:
# ALERT: Gig0/1, down, 1Gbps
# ALERT: WARNING: Interface Gig0/1 is down

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open("network_data.txt", "r") as f:
    for line in f:
        if line.startswith(("O", "B", "S")):
            print("Route:", line.strip())
# Out:
# Route: Switch1, 10.2.1.1, Arista
# Route: O 10.10.10.0/24 via 10.1.1.1
# Route: B 20.20.20.0/24 via 10.1.1.2
# Route: S 30.30.30.0/24 via 10.1.1.3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open("network_data.txt", "r") as f:
    for line in f:
        if "ERROR" in line:
            print("CRITICAL:", line.strip())
# Out:
# CRITICAL: ERROR: Packet drop detected on Gig0/2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
try:
    with open("network_data_missing.txt", "r") as f:
        print(f.read())
except FileNotFoundError:
    print("File not found - check path")
# Out:
# File not found - check path

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
try:
    with open("network_data.txt", "r") as f:
        for line in f:
            name, ip, vendor = line.strip().split(", ")
except ValueError:
    print("Line format mismatch - skipping invalid entries")
# Out:
# Line format mismatch - skipping invalid entries

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
try:
    with open("network_data.txt", "r") as f:
        for line in f:
            if "ERROR" in line:
                print("🚨 Network Issue:", line.strip())
except FileNotFoundError:
    print("Log file missing")
finally:
    print("Log check completed")
# Out:
# 🚨 Network Issue: ERROR: Packet drop detected on Gig0/2
# Log check completed

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
devices = 0
errors = 0

with open("network_data.txt", "r") as f:
    for line in f:
        if "Router" in line or "Switch" in line:
            devices += 1
        if "ERROR" in line:
            errors += 1

print("Devices:", devices)
print("Errors:", errors)
# Out:
# Devices: 3
# Errors: 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open("network_data.2..txt", "a") as f:
    f.write("\nERROR: BGP flapping detected on Router1")

# %%
with open("network_data.2..txt", "r") as file45:
    grab_content = file45.read()
    print(grab_content)
# Out:
# NETWORK ENGINEERING PRACTICE FILE
#
# # Device Inventory
# Router1, 10.1.1.1, Cisco
# Router2, 10.1.1.2, Juniper
# Switch1, 10.2.1.1, Arista
# Firewall1, 10.3.1.1, PaloAlto
#
# # Interface Status
# Gig0/0, up, 1Gbps
# Gig0/1, down, 1Gbps
# Gig0/2, up, 10Gbps
#
# # Routing Table
# O 10.10.10.0/24 via 10.1.1.1
# B 20.20.20.0/24 via 10.1.1.2
# S 30.30.30.0/24 via 10.1.1.3
#
# # Logs
# INFO: BGP session established with 10.1.1.2
# WARNING: Interface Gig0/1 is down
# ERROR: Packet drop detected on Gig0/2
# n Yaswanth added new line to the file to see where the data appends to the Filen Yaswanth added new line to the file to see where the data appends to the FileYaswanth added new line to the file to see where the data appends to the FileYaswanth added new line to the file to see where the data appends to the File/n
# ERROR: BGP flapping detected on Router1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import csv

with open("devices.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["Name", "IP", "Vendor"])
    
    with open("network_data.2..txt", "r") as file:
        for line in file:
            if "," in line:
                writer.writerow(line.strip().split(", "))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import csv

with open("network_devices.csv", "r") as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Device Name', 'IP Address', 'Vendor', 'Status', 'Location']
# ['Router1', '10.1.1.1', 'Cisco', 'Up', 'DC1']
# ['Router2', '10.1.1.2', 'Juniper', 'Down', 'DC2']
# ['Switch1', '10.2.1.1', 'Arista', 'Up', 'DC1']
# ['Firewall1', '10.3.1.1', 'PaloAlto', 'Up', 'DC3']
# ['Router3', '10.1.1.3', 'Cisco', 'Down', 'DC2']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import csv

with open("network_devices.csv", "r") as file:
    reader = csv.reader(file)
    next(reader)  # skip header
    for row in reader:
        print("Device:", row[0], "IP:", row[1])
# Out:
# Device: Router1 IP: 10.1.1.1
# Device: Router2 IP: 10.1.1.2
# Device: Switch1 IP: 10.2.1.1
# Device: Firewall1 IP: 10.3.1.1
# Device: Router3 IP: 10.1.1.3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import csv

with open("network_devices.csv", "r") as file:
    reader = csv.DictReader(file)
    for row in reader:
        if row["Status"] == "Down":
            print("ALERT:", row["Device Name"], "is DOWN")
# Out:
# ALERT: Router2 is DOWN
# ALERT: Router3 is DOWN

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import csv

vendor_count = {}

with open("network_devices.csv", "r") as file:
    reader = csv.DictReader(file)
    for row in reader:
        vendor = row["Vendor"]
        vendor_count[vendor] = vendor_count.get(vendor, 0) + 1

print(vendor_count)
# Out:
# {'Cisco': 2, 'Juniper': 1, 'Arista': 1, 'PaloAlto': 1}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import csv

with open("network_devices.csv", "r") as infile, open("down_devices.csv", "w", newline="") as outfile:
    reader = csv.DictReader(infile)
    writer = csv.DictWriter(outfile, fieldnames=reader.fieldnames)
    
    writer.writeheader()
    
    for row in reader:
        if row["Status"] == "Down":
            writer.writerow(row)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import csv

try:
    with open("network_devices.csv", "r") as file:
        reader = csv.DictReader(file)
        for row in reader:
            print(row["Device Name"])
except FileNotFoundError:
    print("CSV file not found!")
except KeyError:
    print("Column missing in CSV!")
# Out:
# Router1
# Router2
# Switch1
# Firewall1
# Router3

# %% [markdown]
# https://www.linkedin.com/posts/nidhi-gahlot-56a633159_how-to-handle-files-in-python-readcsv-activity-7473060678895812609-alEU?utm_source=share&utm_medium=member_android&rcm=ACoAAC8IlrcBmvwrYuN0lmHmfRzYLS7LMrEqaGM
#
#
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)

# %%
import pandas as pd
df = pd.read_csv("network_devices (1).csv")
print(df)

print(df[df["status"] == "up"])
# Out:
#       hostname         vendor   mgmt_ip status
# 0  rwa01.str15   Cisco IOS-XR  10.1.1.1     Up
# 1  ewa03.str40     Arista EOS  10.1.1.2     Up
# 2   jwa02.bl35  Juniper Junos  10.1.1.3   Down
# Empty DataFrame
# Columns: [hostname, vendor, mgmt_ip, status]
# Index: []

# %%
# !pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: C:\Users\v-yaalam\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: C:\Users\v-yaalam\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd

df = pd.read_excel("bgp_neighbors.xlsx")
print(df)

print(df[df["state"] == "Established"])
# Out:
#    bgp_neighbor        state  prefixes
# 0  PEER-RWA-EWA  Established      2450
# 1  PEER-RWA-JWA         Idle         0
# 2  PEER-EWA-JWA  Established      1980
#    bgp_neighbor        state  prefixes
# 0  PEER-RWA-EWA  Established      2450
# 2  PEER-EWA-JWA  Established      1980

# %%
with open("show_ip_bgp.txt", "r") as f:
    data = f.read()

print(data)
# Out:
# BGP router identifier 10.255.1.1
# Neighbor        State        Prefixes
# 10.3.159.125    Established  2450
# 10.3.159.126    Idle         0

# %%
import json

with open("inventory.json", "r") as f:
    data = json.load(f)

print(data)

for device in data["devices"]:
    print(device["hostname"], device["os"])
# Out:
# {'devices': [{'hostname': 'rwa01.str15', 'role': 'WAN', 'os': 'IOS-XR'}, {'hostname': 'ewa03.str40', 'role': 'WAN', 'os': 'EOS'}]}
# rwa01.str15 IOS-XR
# ewa03.str40 EOS

# %%
with open("wan_events.log", "r") as f:
    for line in f:
        print(line.strip())
# Out:
# 2026-07-10 10:00:01 Interface HundredGigE0/0/0/1 Up
# 2026-07-10 10:05:12 BGP Neighbor 10.3.159.125 Established
# 2026-07-10 10:15:55 ISIS SPF recalculation complete

# %%
df = pd.read_csv("network_devices (1).csv")

# %%
df = pd.read_excel("bgp_neighbors.xlsx")

# %%
df.to_csv("out.csv", index=False)

# %%
df.to_excel("out.xlsx", index=False)

# %%
file = open("show_ip_bgp.txt", "r")
text = file.read()
file.close()

# %%
with open("show_ip_bgp.txt", "r") as f:
    text = f.read()

# %%
with open("show_ip_bgp_1.txt", "w") as f:
    f.write("hello I am Yaswanth Alam an Network Automation Engineer")
