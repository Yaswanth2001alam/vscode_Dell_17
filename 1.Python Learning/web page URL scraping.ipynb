# %%
# !pip install bs4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://packagefeedproxy.microsoft.io/pypi/simple/
# Requirement already satisfied: bs4 in C:\Users\v-yaalam\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in C:\Users\v-yaalam\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from bs4) (4.15.0)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\v-yaalam\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from beautifulsoup4->bs4) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in C:\Users\v-yaalam\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from beautifulsoup4->bs4) (4.15.0)

# %%
import requests
from bs4 import BeautifulSoup

url = "https://example.com"

html = requests.get(url).text
soup = BeautifulSoup(html, "html.parser")

for link in soup.find_all("a", href=True):
    print(link.get_text(strip=True), "->", link["href"])
# Out:
# C:\Users\v-yaalam\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.4.3)/charset_normalizer (3.4.5) doesn't match a supported version!
#   warnings.warn(
# Learn more -> https://iana.org/domains/example

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.github.com"

html = requests.get(url).text
soup = BeautifulSoup(html, "html.parser")

for link in soup.find_all("a", href=True):
    print(link.get_text(strip=True), "->", link["href"])
# Out:
# Skip to content -> #start-of-content
#  -> /
# Sign in -> /login
# GitHub CopilotWrite better code with AI -> https://github.com/features/copilot
# GitHub Copilot appDirect agents from issue to merge -> https://github.com/features/ai/github-app
# MCP RegistryIntegrate external tools -> https://github.com/mcp
# ActionsAutomate any workflow -> https://github.com/features/actions
# CodespacesInstant dev environments -> https://github.com/features/codespaces
# IssuesPlan and track work -> https://github.com/features/issues
# Code ReviewManage code changes -> https://github.com/features/code-review
# Code QualityEnforce quality at merge -> https://github.com/features/code-quality
# GitHub Advanced SecurityFind and fix vulnerabilities -> https://github.com/security/advanced-security
# Code securitySecure your code as you build -> https://github.com/security/advanced-security/code-security
# Secret protectionStop leaks before they start -> https://github.com/security/advanced-security/secret-protection
# Why GitHub -> https://github.com/why-github
# Documentation -> https://docs.github.com
# Blog -> https://github.blog
# Changelog -> https://github.blog/changelog
# Marketplace -> https://github.com/marketplace
# View all features -> https://github.com/features
# Enterprises -> https://github.com/enterprise
# Small and medium teams -> https://github.com/team
# Startups -> https://github.com/enterprise/startups
# Nonprofits -> https://github.com/solutions/industry/nonprofits
# App Modernization -> https://github.com/solutions/use-case/app-modernization
# DevSecOps -> https://github.com/solutions/use-case/devsecops
# DevOps -> https://github.com/solutions/use-case/devops
# CI/CD -> https://github.com/solutions/use-case/ci-cd
# View all use cases -> https://github.com/solutions/use-case
# Healthcare -> https://github.com/solutions/industry/healthcare
# Financial services -> https://github.com/solutions/industry/financial-services
# Manufacturing -> https://github.com/solutions/industry/manufacturing
# Government -> https://github.com/solutions/industry/government
# View all industries -> https://github.com/solutions/industry
# View all solutions -> https://github.com/solutions
# AI -> https://github.com/resources/articles?topic=ai
# Software Development -> https://github.com/resources/articles?topic=software-development
# DevOps -> https://github.com/resources/articles?topic=devops
# Security -> https://github.com/resources/articles?topic=security
# View all topics -> https://github.com/resources/articles
# Customer stories -> https://github.com/customer-stories
# Events & webinars -> https://github.com/resources/events
# Ebooks & reports -> https://github.com/resources/whitepapers
# Business insights -> https://github.com/solutions/executive-insights
# GitHub Skills -> https://skills.github.com
# Documentation -> https://docs.github.com
# Customer support -> https://support.github.com
# Community forum -> https://github.com/orgs/community/discussions
# Trust center -> https://github.com/trust-center
# Partners -> https://github.com/partners
# View all resources -> https://github.com/resources
# GitHub SponsorsFund open source developers -> https://github.com/open-source/sponsors
# Security Lab -> https://securitylab.github.com
# Maintainer Community -> https://maintainers.github.com
# Accelerator -> https://github.com/open-source/accelerator
# GitHub Stars -> https://stars.github.com
# Archive Program -> https://archiveprogram.github.com
# Topics -> https://github.com/topics
# Trending -> https://github.com/trending
# Collections -> https://github.com/collections
# Enterprise platformAI-powered developer platform -> https://github.com/enterprise
# GitHub Advanced SecurityEnterprise-grade security features -> https://github.com/security/advanced-security
# Copilot for BusinessEnterprise-grade AI features -> https://github.com/features/copilot/copilot-business
# Premium SupportEnterprise-grade 24/7 support -> https://github.com/enterprise/premium-support
# Pricing -> https://github.com/pricing
# Sign in -> /login
# Sign up -> /signup?ref_cta=Sign+up&ref_loc=header+logged+out&ref_page=%2F&source=header-home
# Reload ->
# Reload ->
# Reload ->
# Try GitHub Copilot -> /github-copilot/pro
# Explore GitHub Copilot -> /features/copilot
# Read customer story -> /customer-stories/duolingo
# Read industry report -> https://www.gartner.com/reprints/?id=1-2LVTG7RP&ct=250915&st=sb
# Explore GitHub Actions -> /features/actions
# Explore GitHub Codespaces -> /features/codespaces
# Explore GitHub Mobile -> /mobile
# Explore GitHub Marketplace -> /marketplace
# Explore GitHub Advanced Security -> /security/advanced-security
# Learn about GitHub Code Security -> /security/advanced-security/code-security
# Learn about Dependabot -> /security/advanced-security/software-supply-chain
# Learn about GitHub Secret Protection -> /security/advanced-security/secret-protection
# Explore GitHub Projects -> /features/issues
# Explore GitHub Issues -> /features/issues
# Explore GitHub Discussions -> /features/discussions
# Explore code review -> /features/code-review
# Explore GitHub Sponsors -> /sponsors
# TechnologyFigma streamlines development and strengthens securityRead customer story -> /customer-stories/figma
# AutomotiveMercedes-Benz standardizes source code and automates onboardingRead customer story -> /customer-stories/mercedes-benz
# Financial servicesMercado Libre cuts coding time by 50%Read customer story -> /customer-stories/mercado-libre
# Explore customer stories -> /customer-stories
# View all solutions -> /solutions
# Try GitHub Copilot -> /github-copilot/pro
#  -> #hero
#  -> /
# Subscribe -> /newsletter
# Features -> /features
# Enterprise -> /enterprise
# Copilot -> /features/copilot
# AI -> /features/ai
# Security -> /security
# Pricing -> /pricing
# Team -> /team
# Resources -> https://github.com/resources
# Roadmap -> /github/roadmap
# Compare GitHub -> /resources/articles/devops-tools-comparison
# Developer API -> https://docs.github.com/integrations/concepts/about-building-integrations
# Partners -> https://github.com/partners
# Education -> /education
# GitHub CLI -> https://cli.github.com
# GitHub Desktop -> https://github.com/apps/desktop
# GitHub Mobile -> /mobile
# GitHub Marketplace -> /marketplace
# MCP Registry -> /mcp
# Docs -> https://docs.github.com
# Community Forum -> https://github.community
# Professional Services -> https://github.com/services
# Premium Support -> /enterprise/premium-support
# Skills -> https://skills.github.com
# Status -> https://www.githubstatus.com
# Contact GitHub -> https://support.github.com?tags=dotcom-footer
# What is Git? -> /git-guides
# Sitemap -> /sitemap
# About -> /about
# Why GitHub -> /why-github
# Customer Stories -> /customer-stories?type=enterprise
# Blog -> https://github.blog
# The ReadME Project -> /readme
# Careers -> https://github.careers
# Newsroom -> /newsroom
# Inclusion -> /about/diversity
# Social Impact -> https://socialimpact.github.com
# Shop -> https://thegithubshop.com
# Terms -> https://docs.github.com/site-policy/github-terms/github-terms-of-service
# Privacy -> https://docs.github.com/site-policy/privacy-policies/github-general-privacy-statement
# GitHub on LinkedIn -> https://www.linkedin.com/company/github
# GitHub on Instagram -> https://www.instagram.com/github
# GitHub on YouTube -> https://www.youtube.com/github
# GitHub on X -> https://x.com/github
# GitHub on TikTok -> https://www.tiktok.com/@github
# GitHub on Twitch -> https://www.twitch.tv/github
# GitHub’s organization on GitHub -> https://github.com/github

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.youtube.com"

html = requests.get(url).text
soup = BeautifulSoup(html, "html.parser")

for link in soup.find_all("a", href=True):
    print(link.get_text(strip=True), "->", link["href"])
# Out:
#  -> /
#  -> /
# About -> https://www.youtube.com/about/
# Press -> https://www.youtube.com/about/press/
# Copyright -> https://www.youtube.com/about/copyright/
# Contact us -> /t/contact_us/
# Creators -> https://www.youtube.com/creators/
# Advertise -> https://www.youtube.com/ads/
# Developers -> https://developers.google.com/youtube
# Terms -> /t/terms
# Privacy -> /t/privacy
# Policy & Safety -> https://www.youtube.com/about/policies/
# How YouTube works -> https://www.youtube.com/howyoutubeworks?utm_campaign=ytgen&utm_source=ythp&utm_medium=LeftNav&utm_content=txt&u=https%3A%2F%2Fwww.youtube.com%2Fhowyoutubeworks%3Futm_source%3Dythp%26utm_medium%3DLeftNav%26utm_campaign%3Dytgen
# Test new features -> /new
# NFL Sunday Ticket -> https://tv.youtube.com/learn/nflsundayticket

# %%
import requests
from bs4 import BeautifulSoup

url = "https://news.ycombinator.com"

response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

for link in soup.find_all("a", href=True):
    print(f"{link.get_text(strip=True)} -> {link['href']}")
# Out:
#  -> https://news.ycombinator.com
# Hacker News -> news
# new -> newest
# past -> front
# comments -> newcomments
# ask -> ask
# show -> show
# jobs -> jobs
# submit -> submit
# login -> login?goto=news
#  -> vote?id=49452990&how=up&goto=news
# Tailcat – Like netcat, but over Tailscale’s data plane -> https://github.com/tailscale/tailcat
# github.com/tailscale -> from?site=github.com/tailscale
# nderjung -> user?id=nderjung
# 5 hours ago -> item?id=49452990
# hide -> hide?id=49452990&goto=news
# 78 comments -> item?id=49452990
#  -> vote?id=49449507&how=up&goto=news
# GLM-5.3-Flash -> https://z.ai/blog/glm-5.3-flash
# z.ai -> from?site=z.ai
# Philpax -> user?id=Philpax
# 8 hours ago -> item?id=49449507
# hide -> hide?id=49449507&goto=news
# 396 comments -> item?id=49449507
#  -> vote?id=49454419&how=up&goto=news
# Actinide is first startup to produce high-assay low-enriched uranium (HALEU) -> https://www.actinideinc.com/press/actinide-becomes-first-startup-to-ever-enrich-natural-uranium-to-produce-haleu
# actinideinc.com -> from?site=actinideinc.com
# dsalzman -> user?id=dsalzman
# 3 hours ago -> item?id=49454419
# hide -> hide?id=49454419&goto=news
# 54 comments -> item?id=49454419
#  -> vote?id=49448321&how=up&goto=news
# AWS Acquires DuckLabs -> https://ducklabs.com/news/2026/08/26/ducklabs-to-join-aws
# ducklabs.com -> from?site=ducklabs.com
# onderkalaci -> user?id=onderkalaci
# 9 hours ago -> item?id=49448321
# hide -> hide?id=49448321&goto=news
# 272 comments -> item?id=49448321
#  -> vote?id=49452980&how=up&goto=news
# An ongoing 3D-printer AGPL violation -> https://lwn.net/SubscriberLink/1089390/46116614cc74b814/
# lwn.net -> from?site=lwn.net
# Velocifyer -> user?id=Velocifyer
# 5 hours ago -> item?id=49452980
# hide -> hide?id=49452980&goto=news
# 112 comments -> item?id=49452980
#  -> vote?id=49454728&how=up&goto=news
# GitHub Outage Tracker: Is GitHub Cooked? -> https://isgithubcooked.com/
# isgithubcooked.com -> from?site=isgithubcooked.com
# toomanyrichies -> user?id=toomanyrichies
# 3 hours ago -> item?id=49454728
# hide -> hide?id=49454728&goto=news
# 47 comments -> item?id=49454728
#  -> vote?id=49454314&how=up&goto=news
# The Hugging Face incident and the road ahead -> https://openai.com/index/hugging-face-incident-and-the-road-ahead/
# openai.com -> from?site=openai.com
# amrrs -> user?id=amrrs
# 3 hours ago -> item?id=49454314
# hide -> hide?id=49454314&goto=news
# 119 comments -> item?id=49454314
#  -> vote?id=49454764&how=up&goto=news
# Serve Markdown to AI Agents with Accept Headers -> https://acceptmarkdown.com/
# acceptmarkdown.com -> from?site=acceptmarkdown.com
# tilt -> user?id=tilt
# 3 hours ago -> item?id=49454764
# hide -> hide?id=49454764&goto=news
# 24 comments -> item?id=49454764
#  -> vote?id=49452671&how=up&goto=news
# CoMaps: The Offline App That Guided Rescuers Without a Signal in Venezuela -> https://hotosm.org/en/news/comaps-the-offline-app-that-guided-rescuers-without-a-signal-in-the-venezuela-response/
# hotosm.org -> from?site=hotosm.org
# gedankenstuecke -> user?id=gedankenstuecke
# 5 hours ago -> item?id=49452671
# hide -> hide?id=49452671&goto=news
# 38 comments -> item?id=49452671
#  -> vote?id=49448210&how=up&goto=news
# Qwen3.8-Flash-Next -> https://qwen.ai/blog?id=qwen3.8-flash-next
# qwen.ai -> from?site=qwen.ai
# tosh -> user?id=tosh
# 9 hours ago -> item?id=49448210
# hide -> hide?id=49448210&goto=news
# 193 comments -> item?id=49448210
#  -> vote?id=49450722&how=up&goto=news
# Disruption with Some GitHub Services -> https://www.githubstatus.com/incidents/hcbtzksccj2f
# githubstatus.com -> from?site=githubstatus.com
# blimmer -> user?id=blimmer
# 7 hours ago -> item?id=49450722
# hide -> hide?id=49450722&goto=news
# 151 comments -> item?id=49450722
#  -> vote?id=49450448&how=up&goto=news
# Nebula Sans -> https://www.nebulasans.com
# nebulasans.com -> from?site=nebulasans.com
# GavinAnderegg -> user?id=GavinAnderegg
# 7 hours ago -> item?id=49450448
# hide -> hide?id=49450448&goto=news
# 123 comments -> item?id=49450448
#  -> vote?id=49451675&how=up&goto=news
# FDA Approves First in Class Targeted Therapy for Metastatic Pancreatic Cancer -> https://www.fda.gov/news-events/press-announcements/fda-approves-first-class-targeted-therapy-metastatic-pancreatic-cancer
# fda.gov -> from?site=fda.gov
# leopoldj -> user?id=leopoldj
# 6 hours ago -> item?id=49451675
# hide -> hide?id=49451675&goto=news
# 27 comments -> item?id=49451675
#  -> vote?id=49449576&how=up&goto=news
# Twitter Viewer – View Twitter Without Account -> https://twitterwebviewer.com/
# twitterwebviewer.com -> from?site=twitterwebviewer.com
# motownphilly -> user?id=motownphilly
# 8 hours ago -> item?id=49449576
# hide -> hide?id=49449576&goto=news
# 134 comments -> item?id=49449576
#  -> vote?id=49455530&how=up&goto=news
# mold: A Parallel Linker -> https://arxiv.org/abs/2608.23228
# arxiv.org -> from?site=arxiv.org
# matt_d -> user?id=matt_d
# 2 hours ago -> item?id=49455530
# hide -> hide?id=49455530&goto=news
# 3 comments -> item?id=49455530
#  -> vote?id=49451448&how=up&goto=news
# Tim Curry has died -> https://www.theguardian.com/film/2026/aug/26/tim-curry-dies-rocky-horror-show-stephen-king-it-legend-film
# theguardian.com -> from?site=theguardian.com
# mykowebhn -> user?id=mykowebhn
# 6 hours ago -> item?id=49451448
# hide -> hide?id=49451448&goto=news
# 184 comments -> item?id=49451448
#  -> vote?id=49452037&how=up&goto=news
# Show HN: Build your own theme park -> https://www.magicpatterns.com/theme-park
# magicpatterns.com -> from?site=magicpatterns.com
# thealexanderlee -> user?id=thealexanderlee
# 2 hours ago -> item?id=49452037
# hide -> hide?id=49452037&goto=news
# 11 comments -> item?id=49452037
#  -> vote?id=49456929&how=up&goto=news
# Worst-case glacial lake flood scenarios in a transboundary Himalayan basin 2022 -> https://nhess.copernicus.org/articles/22/3765/2022/nhess-22-3765-2022.html
# copernicus.org -> from?site=copernicus.org
# totetsu -> user?id=totetsu
# 5 minutes ago -> item?id=49456929
# hide -> hide?id=49456929&goto=news
# discuss -> item?id=49456929
#  -> vote?id=49395802&how=up&goto=news
# Stalking the Wily Hacker: 40 years later – Cliff Stoll [video] -> https://www.youtube.com/watch?v=656058JxTM0
# youtube.com -> from?site=youtube.com
# zoenolan -> user?id=zoenolan
# 18 hours ago -> item?id=49395802
# hide -> hide?id=49395802&goto=news
# 85 comments -> item?id=49395802
#  -> vote?id=49449749&how=up&goto=news
# Taylor Farms: How One Company's Reach Became a National Risk -> https://farmaction.us/taylorfarmsreport/
# farmaction.us -> from?site=farmaction.us
# speckx -> user?id=speckx
# 8 hours ago -> item?id=49449749
# hide -> hide?id=49449749&goto=news
# 146 comments -> item?id=49449749
#  -> vote?id=49455613&how=up&goto=news
# What will be left for us to work on -> https://ICML.cc/virtual/2026/invited-talk/67274
# icml.cc -> from?site=icml.cc
# Cloudly -> user?id=Cloudly
# 2 hours ago -> item?id=49455613
# hide -> hide?id=49455613&goto=news
# 23 comments -> item?id=49455613
#  -> vote?id=49450898&how=up&goto=news
# It’s so hard to finish an idea that is not yours and is just suggested by AI -> https://www.ssp.sh/brain/using-obsidian-with-ai/
# ssp.sh -> from?site=ssp.sh
# zazuke -> user?id=zazuke
# 7 hours ago -> item?id=49450898
# hide -> hide?id=49450898&goto=news
# 83 comments -> item?id=49450898
#  -> vote?id=49452789&how=up&goto=news
# YouTube Format IDs -> https://gist.github.com/MartinEesmaa/2f4b261cb90a47e9c41ba115a011a4aa
# gist.github.com -> from?site=gist.github.com
# ksec -> user?id=ksec
# 5 hours ago -> item?id=49452789
# hide -> hide?id=49452789&goto=news
# 43 comments -> item?id=49452789
#  -> vote?id=49455450&how=up&goto=news
# Infrastructure as Raclette -> https://lois.postu.la/posts/infrastructure-as-a-raclette
# postu.la -> from?site=postu.la
# kasmanit -> user?id=kasmanit
# 2 hours ago -> item?id=49455450
# hide -> hide?id=49455450&goto=news
# 2 comments -> item?id=49455450
#  -> vote?id=49449128&how=up&goto=news
# Access to Urban Woodlands Linked with Lower Use of Antidepressants -> https://e360.yale.edu/digest/scotland-woodlands-antidepressants
# yale.edu -> from?site=yale.edu
# speckx -> user?id=speckx
# 9 hours ago -> item?id=49449128
# hide -> hide?id=49449128&goto=news
# 13 comments -> item?id=49449128
#  -> vote?id=49445727&how=up&goto=news
# RAG Is Simpler Than You Think -> https://www.lighthousenewsletter.com/p/rag-is-simpler-than-you-think
# lighthousenewsletter.com -> from?site=lighthousenewsletter.com
# j0selit0 -> user?id=j0selit0
# 14 hours ago -> item?id=49445727
# hide -> hide?id=49445727&goto=news
# 175 comments -> item?id=49445727
#  -> vote?id=49449888&how=up&goto=news
# PageRank explained -> https://praveshkoirala.com/2026/08/26/you-could-have-invented-pagerank/
# praveshkoirala.com -> from?site=praveshkoirala.com
# pkoird -> user?id=pkoird
# 8 hours ago -> item?id=49449888
# hide -> hide?id=49449888&goto=news
# 80 comments -> item?id=49449888
# Proliferate (YC S25) Is Hiring -> https://www.ycombinator.com/companies/proliferate/jobs/OgpCKYJ-founding-product-engineer
# ycombinator.com -> from?site=ycombinator.com
# 10 hours ago -> item?id=49447480
# hide -> hide?id=49447480&goto=news
#  -> vote?id=49455956&how=up&goto=news
# Clerky Is Joining Stripe -> https://www.clerky.com/blog/clerky-is-joining-stripe
# clerky.com -> from?site=clerky.com
# zakshay -> user?id=zakshay
# 1 hour ago -> item?id=49455956
# hide -> hide?id=49455956&goto=news
# 1 comment -> item?id=49455956
#  -> vote?id=49455557&how=up&goto=news
# Show HN: We built the smallest dual-band aircraft tracker -> https://pantsforbirds.com/the-worlds-smallest-dual-band-ads-b-receiver-module/
# pantsforbirds.com -> from?site=pantsforbirds.com
# CoolNamesAllTkn -> user?id=CoolNamesAllTkn
# 2 hours ago -> item?id=49455557
# hide -> hide?id=49455557&goto=news
# 2 comments -> item?id=49455557
# More -> ?p=2
# Guidelines -> newsguidelines.html
# FAQ -> newsfaq.html
# Lists -> lists
# API -> https://github.com/HackerNews/API
# Security -> security.html
# Legal -> https://www.ycombinator.com/legal/
# Apply to YC -> https://www.ycombinator.com/apply/
# Contact -> mailto:hn@ycombinator.com
