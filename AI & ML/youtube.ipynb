# %%
print("Hello")
# Out:
# Hello

# %%
# !pip install yt_dlp
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://packagefeedproxy.microsoft.io/pypi/simple/
# Collecting yt_dlp
#   Downloading yt_dlp-2026.8.19-py3-none-any.whl (3.2 MB)
#      ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#      ---------------------------------------- 3.2/3.2 MB 38.6 MB/s  0:00:00
# Installing collected packages: yt_dlp
# Successfully installed yt_dlp-2026.8.19

# %%
from yt_dlp import YoutubeDL

url = input("Enter YouTube URL: ")
options = {
    "format": "bv*+ba/b",
    "merge_output_format": "mp4",
}
with YoutubeDL(options) as ydl:
    ydl.download([url])
# Out:
# [generic] Extracting URL:
# ERROR: [generic] '' is not a valid URL
# ---------------------------------------------------------------------------
# ExtractorError                            Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\yt_dlp\YoutubeDL.py:1731, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1730 try:
# -> 1731     return func(self, *args, **kwargs)
#    1732 except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\yt_dlp\YoutubeDL.py:1866, in YoutubeDL.__extract_info(self, url, ie, download, extra_info, process)
#    1865 try:
# -> 1866     ie_result = ie.extract(url)
#    1867 except UserNotLive as e:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\yt_dlp\extractor\common.py:765, in InfoExtractor.extract(self, url)
#     763 self.to_screen('Extracting URL: %s' % (
#     764     url if self.get_param('verbose') else truncate_string(url, 100, 20)))
# --> 765 ie_result = self._real_extract(url)
#     766 if ie_result is None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\yt_dlp\extractor\generic.py:789, in GenericIE._real_extract(self, url)
#     788 if default_search in ('error', 'fixup_error'):
# --> 789     raise ExtractorError(f'{url!r} is not a valid URL', expected=True)
#     790 else:
#
# ExtractorError: [generic] '' is not a valid URL
#
# During handling of the above exception, another exception occurred:
#
# DownloadError                             Traceback (most recent call last)
# Cell In[5], line 9
#       4 options = {
#       5     "format": "bv*+ba/b",
#       6     "merge_output_format": "mp4",
#       7 }
#       8 with YoutubeDL(options) as ydl:
# ----> 9     ydl.download([url])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\yt_dlp\YoutubeDL.py:3714, in YoutubeDL.download(self, url_list)
#    3711     raise SameFileError(outtmpl)
#    3713 for url in url_list:
# -> 3714     self.__download_wrapper(self.extract_info)(
#    3715         url, force_generic_extractor=self.params.get('force_generic_extractor', False))
#    3717 return self._download_retcode
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\yt_dlp\YoutubeDL.py:3687, in YoutubeDL.__download_wrapper.<locals>.wrapper(*args, **kwargs)
#    3684 @functools.wraps(func)
#    3685 def wrapper(*args, **kwargs):
#    3686     try:
# -> 3687         res = func(*args, **kwargs)
#    3688     except CookieLoadError:
#    3689         raise
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\yt_dlp\YoutubeDL.py:1720, in YoutubeDL.extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#    1718             raise ExistingVideoReached
#    1719         break
# -> 1720     return self.__extract_info(url, self.get_info_extractor(key), download, extra_info, process)
#    1721 else:
#    1722     extractors_restricted = self.params.get('allowed_extractors') not in (None, ['default'])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\yt_dlp\YoutubeDL.py:1749, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1747     self.report_error(msg)
#    1748 except ExtractorError as e:  # An error we somewhat expected
# -> 1749     self.report_error(str(e), e.format_traceback())
#    1750 except Exception as e:
#    1751     if self.params.get('ignoreerrors'):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\yt_dlp\YoutubeDL.py:1165, in YoutubeDL.report_error(self, message, *args, **kwargs)
#    1160 def report_error(self, message, *args, **kwargs):
#    1161     """
#    1162     Do the same as trouble, but prefixes the message with 'ERROR:', colored
#    1163     in red if stderr is a tty file.
#    1164     """
# -> 1165     self.trouble(f'{self._format_err("ERROR:", self.Styles.ERROR)} {message}', *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\yt_dlp\YoutubeDL.py:1103, in YoutubeDL.trouble(self, message, tb, is_error)
#    1101     else:
#    1102         exc_info = sys.exc_info()
# -> 1103     raise DownloadError(message, exc_info)
#    1104 self._download_retcode = 1
#
# DownloadError: ERROR: [generic] '' is not a valid URL
