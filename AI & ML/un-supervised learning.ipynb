# %% [markdown]
# Here are common **Unsupervised Learning** models with Python examples using `scikit-learn`.
#
# Unsupervised learning means **no labeled output (y)** — the model tries to find patterns, clusters, or structure in data.
#
# ---
#
# # 🔹 1. K-Means Clustering
#
# Used to group data into K clusters.
#
# ```python
# from sklearn.cluster import KMeans
# from sklearn.datasets import make_blobs
# import matplotlib.pyplot as plt
#
# # Generate sample data
# X, _ = make_blobs(n_samples=300, centers=3, random_state=42)
#
# # Create model
# model = KMeans(n_clusters=3, random_state=42)
#
# # Train model
# model.fit(X)
#
# # Predict cluster labels
# labels = model.predict(X)
#
# # Plot clusters
# plt.scatter(X[:, 0], X[:, 1], c=labels)
# plt.title("K-Means Clustering")
# plt.show()
# ```
#
# ---
#
# # 🔹 2. Hierarchical Clustering (Agglomerative)
#
# Builds clusters step-by-step (bottom-up).
#
# ```python
# from sklearn.cluster import AgglomerativeClustering
# from sklearn.datasets import make_blobs
# import matplotlib.pyplot as plt
#
# # Generate data
# X, _ = make_blobs(n_samples=200, centers=3, random_state=42)
#
# # Create model
# model = AgglomerativeClustering(n_clusters=3)
#
# # Fit and predict
# labels = model.fit_predict(X)
#
# # Plot
# plt.scatter(X[:, 0], X[:, 1], c=labels)
# plt.title("Hierarchical Clustering")
# plt.show()
# ```
#
# ---
#
# # 🔹 3. DBSCAN (Density-Based Clustering)
#
# Groups points based on density (good for noise detection).
#
# ```python
# from sklearn.cluster import DBSCAN
# from sklearn.datasets import make_moons
# import matplotlib.pyplot as plt
#
# # Generate non-linear dataset
# X, _ = make_moons(n_samples=300, noise=0.05)
#
# # Create model
# model = DBSCAN(eps=0.3, min_samples=5)
#
# # Fit and predict
# labels = model.fit_predict(X)
#
# # Plot
# plt.scatter(X[:, 0], X[:, 1], c=labels)
# plt.title("DBSCAN Clustering")
# plt.show()
# ```
#
# ---
#
# # 🔹 4. Principal Component Analysis (PCA)
#
# Used for dimensionality reduction.
#
# ```python
# from sklearn.decomposition import PCA
# from sklearn.datasets import load_iris
# import matplotlib.pyplot as plt
#
# # Load data
# data = load_iris()
# X = data.data
#
# # Create PCA model
# pca = PCA(n_components=2)
#
# # Transform data
# X_reduced = pca.fit_transform(X)
#
# # Plot
# plt.scatter(X_reduced[:, 0], X_reduced[:, 1])
# plt.title("PCA Dimensionality Reduction")
# plt.xlabel("Principal Component 1")
# plt.ylabel("Principal Component 2")
# plt.show()
# ```
#
# ---
#
# # 🔹 5. t-SNE (Dimensionality Reduction)
#
# Used for visualization of high-dimensional data.
#
# ```python
# from sklearn.manifold import TSNE
# from sklearn.datasets import load_iris
# import matplotlib.pyplot as plt
#
# # Load data
# data = load_iris()
# X = data.data
#
# # Create model
# tsne = TSNE(n_components=2, random_state=42)
#
# # Transform
# X_embedded = tsne.fit_transform(X)
#
# # Plot
# plt.scatter(X_embedded[:, 0], X_embedded[:, 1])
# plt.title("t-SNE Visualization")
# plt.show()
# ```
#
# ---
#
# # 🔹 6. Autoencoder (Neural Network Based)
#
# Used for dimensionality reduction or anomaly detection.
#
# ```python
# import tensorflow as tf
# from tensorflow.keras import layers
# import numpy as np
#
# # Generate dummy data
# X = np.random.rand(1000, 20)
#
# # Define autoencoder
# input_layer = layers.Input(shape=(20,))
# encoded = layers.Dense(10, activation='relu')(input_layer)
# decoded = layers.Dense(20, activation='sigmoid')(encoded)
#
# autoencoder = tf.keras.Model(input_layer, decoded)
# autoencoder.compile(optimizer='adam', loss='mse')
#
# # Train
# autoencoder.fit(X, X, epochs=10, batch_size=32)
#
# # Encoded representation
# encoder = tf.keras.Model(input_layer, encoded)
# encoded_data = encoder.predict(X)
# ```
#
# ---
#
# # 🔹 7. Gaussian Mixture Model (GMM)
#
# Probabilistic clustering model.
#
# ```python
# from sklearn.mixture import GaussianMixture
# from sklearn.datasets import make_blobs
# import matplotlib.pyplot as plt
#
# # Generate data
# X, _ = make_blobs(n_samples=300, centers=3, random_state=42)
#
# # Create model
# model = GaussianMixture(n_components=3)
#
# # Train model
# model.fit(X)
#
# # Predict cluster labels
# labels = model.predict(X)
#
# # Plot
# plt.scatter(X[:, 0], X[:, 1], c=labels)
# plt.title("Gaussian Mixture Model")
# plt.show()
# ```
#
# ---
#
# # 🔹 8. Isolation Forest (Anomaly Detection)
#
# Used for detecting anomalies in data.
#
# ```python
# from sklearn.ensemble import IsolationForest
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Generate normal data
# X = 0.3 * np.random.randn(100, 2)
# X_outliers = np.random.uniform(low=-4, high=4, size=(20, 2))
# X = np.vstack([X, X_outliers])
#
# # Create model
# model = IsolationForest(contamination=0.1)
#
# # Fit and predict
# labels = model.fit_predict(X)
#
# # Plot
# plt.scatter(X[:, 0], X[:, 1], c=labels)
# plt.title("Isolation Forest Anomaly Detection")
# plt.show()
# ```
#
# ---
#
# # 🔥 Summary of Unsupervised Algorithms
#
# | Category                 | Algorithms                         |
# | ------------------------ | ---------------------------------- |
# | Clustering               | K-Means, Hierarchical, DBSCAN, GMM |
# | Dimensionality Reduction | PCA, t-SNE, Autoencoders           |
# | Anomaly Detection        | Isolation Forest                   |
# | Density Estimation       | GMM, KDE                           |
#
# ---
#
# If you want, I can next:
#
# * ✅ Give network automation related real-world examples
# * ✅ Explain when to use which algorithm
# * ✅ Give interview-focused ML explanations
# * ✅ Show comparison between supervised vs unsupervised
#
# Just tell me what you want next 🚀

# %% [markdown]
# Here are common Unsupervised Learning models with Python examples using scikit-learn.
#
# Unsupervised learning means no labeled output (y) — the model tries to find patterns, clusters, or structure in data.

# %%
print("Hello")
# Out:
# Hello

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /home/codespace/.python/current/lib/python3.12/site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in /home/codespace/.python/current/lib/python3.12/site-packages (from scikit-learn) (2.4.2)
# Requirement already satisfied: scipy>=1.10.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from scikit-learn) (3.6.0)

# %% [markdown]
# K-Means Clustering
#
# Used to group data into K clusters.

# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# Generate sample data
X, _ = make_blobs(n_samples=300, centers=3, random_state=42)

# Create model
model = KMeans(n_clusters=3, random_state=42)

# Train model
model.fit(X)

# Predict cluster labels
labels = model.predict(X)

# Plot clusters
plt.scatter(X[:, 0], X[:, 1], c=labels)
plt.title("K-Means Clustering")
plt.show()

# %% [markdown]
# . Hierarchical Clustering (Agglomerative)
#
# Builds clusters step-by-step (bottom-up).

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# Generate data
X, _ = make_blobs(n_samples=200, centers=3, random_state=42)

# Create model
model = AgglomerativeClustering(n_clusters=3)

# Fit and predict
labels = model.fit_predict(X)

# Plot
plt.scatter(X[:, 0], X[:, 1], c=labels)
plt.title("Hierarchical Clustering")
plt.show()

# %% [markdown]
# DBSCAN (Density-Based Clustering)
#
# Groups points based on density (good for noise detection).

# %%
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt

# Generate non-linear dataset
X, _ = make_moons(n_samples=300, noise=0.05)

# Create model
model = DBSCAN(eps=0.3, min_samples=5)

# Fit and predict
labels = model.fit_predict(X)

# Plot
plt.scatter(X[:, 0], X[:, 1], c=labels)
plt.title("DBSCAN Clustering")
plt.show()

# %% [markdown]
# Principal Component Analysis (PCA)
#
# Used for dimensionality reduction.

# %%
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

# Load data
data = load_iris()
X = data.data

# Create PCA model
pca = PCA(n_components=2)

# Transform data
X_reduced = pca.fit_transform(X)

# Plot
plt.scatter(X_reduced[:, 0], X_reduced[:, 1])
plt.title("PCA Dimensionality Reduction")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.show()

# %% [markdown]
# t-SNE (Dimensionality Reduction)
#
# Used for visualization of high-dimensional data.

# %%
from sklearn.manifold import TSNE
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

# Load data
data = load_iris()
X = data.data

# Create model
tsne = TSNE(n_components=2, random_state=42)

# Transform
X_embedded = tsne.fit_transform(X)

# Plot
plt.scatter(X_embedded[:, 0], X_embedded[:, 1])
plt.title("t-SNE Visualization")
plt.show()

# %% [markdown]
# Autoencoder (Neural Network Based)
#
# Used for dimensionality reduction or anomaly detection.

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /home/codespace/.python/current/lib/python3.12/site-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/codespace/.python/current/lib/python3.12/site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/codespace/.python/current/lib/python3.12/site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /home/codespace/.python/current/lib/python3.12/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /home/codespace/.python/current/lib/python3.12/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /home/codespace/.local/lib/python3.12/site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from tensorflow) (7.34.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/codespace/.local/lib/python3.12/site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in /home/codespace/.local/lib/python3.12/site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in /home/codespace/.local/lib/python3.12/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /home/codespace/.local/lib/python3.12/site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from tensorflow) (2.1.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/codespace/.python/current/lib/python3.12/site-packages (from tensorflow) (1.78.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from tensorflow) (2.4.2)
# Requirement already satisfied: h5py>=3.11.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /home/codespace/.python/current/lib/python3.12/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in /home/codespace/.python/current/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (3.10.2)
# Requirement already satisfied: pillow in /home/codespace/.python/current/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (12.1.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/codespace/.python/current/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.6)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: rich in /home/codespace/.python/current/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow) (14.3.3)
# Requirement already satisfied: namex in /home/codespace/.python/current/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /home/codespace/.python/current/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow) (0.19.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /home/codespace/.local/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/codespace/.local/lib/python3.12/site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/codespace/.python/current/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)

# %%
import tensorflow as tf
from tensorflow.keras import layers
import numpy as np

# Generate dummy data
X = np.random.rand(1000, 20)

# Define autoencoder
input_layer = layers.Input(shape=(20,))
encoded = layers.Dense(10, activation='relu')(input_layer)
decoded = layers.Dense(20, activation='sigmoid')(encoded)

autoencoder = tf.keras.Model(input_layer, decoded)
autoencoder.compile(optimizer='adam', loss='mse')

# Train
autoencoder.fit(X, X, epochs=10, batch_size=32)

# Encoded representation
encoder = tf.keras.Model(input_layer, encoded)
encoded_data = encoder.predict(X)
# Out:
# 2026-03-04 19:43:16.170801: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/10
# 2026-03-04 19:43:20.218353: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0859
# Epoch 2/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0820
# Epoch 3/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0800
# Epoch 4/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0779
# Epoch 5/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0754
# Epoch 6/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0729
# Epoch 7/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0706
# Epoch 8/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0684
# Epoch 9/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0663
# Epoch 10/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0645
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# Gaussian Mixture Model (GMM)
#
# Probabilistic clustering model.

# %%
from sklearn.mixture import GaussianMixture
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# Generate data
X, _ = make_blobs(n_samples=300, centers=3, random_state=42)

# Create model
model = GaussianMixture(n_components=3)

# Train model
model.fit(X)

# Predict cluster labels
labels = model.predict(X)

# Plot
plt.scatter(X[:, 0], X[:, 1], c=labels)
plt.title("Gaussian Mixture Model")
plt.show()

# %% [markdown]
# . Isolation Forest (Anomaly Detection)
#
# Used for detecting anomalies in data.

# %%
from sklearn.ensemble import IsolationForest
import numpy as np
import matplotlib.pyplot as plt

# Generate normal data
X = 0.3 * np.random.randn(100, 2)
X_outliers = np.random.uniform(low=-4, high=4, size=(20, 2))
X = np.vstack([X, X_outliers])

# Create model
model = IsolationForest(contamination=0.1)

# Fit and predict
labels = model.fit_predict(X)

# Plot
plt.scatter(X[:, 0], X[:, 1], c=labels)
plt.title("Isolation Forest Anomaly Detection")
plt.show()

# %%
import pandas as pd
from sklearn.ensemble import IsolationForest

# Example network telemetry dataset
data = pd.DataFrame({
    "in_bps": [200, 220, 210, 205, 5000],
    "out_bps": [180, 190, 175, 200, 6000],
    "cpu": [30, 35, 32, 29, 95]
})

model = IsolationForest(contamination=0.2)
data["anomaly"] = model.fit_predict(data)

print(data)
# Out:
#    in_bps  out_bps  cpu  anomaly
# 0     200      180   30        1
# 1     220      190   35        1
# 2     210      175   32        1
# 3     205      200   29        1
# 4    5000     6000   95       -1

# %%
from sklearn.cluster import KMeans
import pandas as pd

data = pd.DataFrame({
    "interfaces": [48, 48, 8, 8],
    "bgp_peers": [2, 3, 20, 18],
    "traffic_gbps": [10, 12, 40, 38]
})

kmeans = KMeans(n_clusters=2)
data["cluster"] = kmeans.fit_predict(data)

print(data)
# Out:
#    interfaces  bgp_peers  traffic_gbps  cluster
# 0          48          2            10        1
# 1          48          3            12        1
# 2           8         20            40        0
# 3           8         18            38        0

# %%
from sklearn.cluster import KMeans
import pandas as pd

data = pd.DataFrame({
    "interfaces": [48, 48, 8, 8],
    "bgp_peers": [2, 3, 20, 18],
    "traffic_gbps": [10, 12, 40, 38]
})

kmeans = KMeans(n_clusters=2)
data["cluster"] = kmeans.fit_predict(data)

print(data)
# Out:
#    interfaces  bgp_peers  traffic_gbps  cluster
# 0          48          2            10        1
# 1          48          3            12        1
# 2           8         20            40        0
# 3           8         18            38        0

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

logs = [
    "BGP neighbor down",
    "BGP neighbor reset",
    "Interface Gi0/1 down",
    "Interface Gi0/1 up"
]

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(logs)

kmeans = KMeans(n_clusters=2)
labels = kmeans.fit_predict(X)

print(labels)
# Out:
# [0 0 1 1]

# %%
from sklearn.decomposition import PCA
import numpy as np

data = np.random.rand(100, 10)  # 10 telemetry features

pca = PCA(n_components=2)
reduced = pca.fit_transform(data)

print(reduced.shape)
# Out:
# (100, 2)
