# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# https://youtu.be/Nzq6fEr9SJ4
#
#                                                                                 About Ansible.
# Ansible consists of playbooks.
#
# Playbooks are return in yaml files.
#
#
#
# yaml will leverage the modules to function.
#
#
# Modules will have create VM, [public IP], do somehting.
#
#
# ![image.png](attachment:image.png)
#
#
#
#
# Who is engaging with Ansible:
#
#     Storage, networking, SME.

# %% [markdown]
#                                         About Python
#
#
# Python imports codes and runs it.
#
#
#  Who uses it:       SME, python programmer
#
#
# Python will have complex automation modules and tasks to do for us.

# %% [markdown]
# When to use Python and Ansible:
#
#
# Ansible is written on the backbone of python.
