# %%
print("Hello")
# Out:
# Hello

# %%
def test(x=[]):
    x.append(1)
    print(x)

test()
test()
# Out:
# [1]
# [1, 1]

# %%
def test(x=None):
    if x is None:
        x = []
    x.append(1)
    print(x)

test()
test()
# Out:
# [1]
# [1]

# %% [markdown]
# Let’s break this down step by step 👇
#
# ### ✅ Your code
#
# ```python
# def test(x=[]):
#     x.append(1)
#     print(x)
#
# test()
# test()
# ```
#
# ***
#
# ## 🔹 Key Concept: Mutable Default Argument
#
# * The parameter `x=[]` is a **default argument**.
# * In Python, **default arguments are evaluated only once**, when the function is defined (not every time it's called).
# * Lists are **mutable objects** → meaning they can be changed.
#
# ***
#
# ## 🔹 Step-by-step execution
#
# ### ✅ First call → `test()`
#
# * `x` is not passed → uses default `[]`
#
# * Inside function:
#   ```python
#   x.append(1)
#   ```
#   Now `x = [1]`
#
# * Output:
#   ```
#   [1]
#   ```
#
# ***
#
# ### ✅ Second call → `test()`
#
# * Again `x` is not passed → BUT Python reuses the same default list (not a new one)
#
# * So now:
#   * Previous `x` was already `[1]`
#   * `x.append(1)` → now `[1, 1]`
#
# * Output:
#   ```
#   [1, 1]
#   ```
#
# ***
#
# ## 🔹 Final Output
#
# ```
# [1]
# [1, 1]
# ```
#
# ***
#
# ## 🚨 Why this matters (important!)
#
# This behavior can cause **bugs** because you might expect a fresh list each time, but Python keeps modifying the same list.
#
# ***
#
# ## ✅ Correct way (if you want a new list each time)
#
# ```python
# def test(x=None):
#     if x is None:
#         x = []
#     x.append(1)
#     print(x)
#
# test()
# test()
# ```
#
# ### ✅ Output now:
#
# ```
# [1]
# [1]
# ```
#
# ***
#
# ## 🧠 Summary
#
# * Default arguments are created **once**.
# * Mutable objects (like lists, dicts) will **persist changes** across function calls.
# * Use `None` as a safe default and initialize inside the function.
#
# ***
#
# If you want, I can show a similar example with **dictionaries or real debugging scenarios** (very useful in interviews + projects).

# %%
def value(a, b=5, c=10):
    print(a+b+c)

value(5, c=20)
# Out:
# 30

# %%
value(5)
# Out:
# 20

# %%
value(5,7)
# Out:
# 22

# %%
value(5,7,8)
# Out:
# 20

# %% [markdown]
# value(5)
# # 5 + 5 + 10 = 20
#
# value(5, 7)
# # a=5, b=7, c=10 → 22
#
# value(5, 7, 8)
# # a=5, b=7, c=8 → 20

# %% [markdown]
# Let’s walk through this clearly 👇
#
# ***
#
# ## ✅ Your code
#
# ```python
# def value(a, b=5, c=10):
#     print(a + b + c)
#
# value(5, c=20)
# ```
#
# ***
#
# ## 🔹 Step-by-step execution
#
# ### Function definition:
#
# ```python
# def value(a, b=5, c=10):
# ```
#
# * `a` → required argument
# * `b=5` → default value is 5
# * `c=10` → default value is 10
#
# ***
#
# ### Function call:
#
# ```python
# value(5, c=20)
# ```
#
# * `a = 5` (from first positional argument)
# * `c = 20` (explicitly provided as keyword argument)
# * `b` is **not provided**, so it takes default → `b = 5`
#
# ***
#
# ## 🔹 Calculation
#
# ```
# a + b + c
# = 5 + 5 + 20
# = 30
# ```
#
# ***
#
# ## ✅ Final Output
#
# ```
# 30
# ```
#
# ***
#
# ## 🧠 Key Concept
#
# * You can **skip middle default arguments** only if you use **keyword arguments**.
# * Python matches:
#   * Positional first (`a`)
#   * Then named (`c=20`)
#   * Remaining (`b`) stays default
#
# ***
#
# ## 🚀 Extra examples
#
# ```python
# value(5)
# # 5 + 5 + 10 = 20
#
# value(5, 7)
# # a=5, b=7, c=10 → 22
#
# value(5, 7, 8)
# # a=5, b=7, c=8 → 20
# ```
#
# ***
#
# If you want, I can explain \*\*argument ordering rules (positional vs keyword vs \*args/**kwargs)** — very useful for interviews and real projects.

# %%
def func():
    pass

print(func())
# Out:
# None

# %%
def func():
    return 5

print(func())
# Out:
# 5

# %%
def func():
    pass

# %%
x = 10

def demo():
    x = 5
    print(x)
demo()
print(x)
# Out:
# 5
# 10

# %%
x = 10

def demo():
    global x
    x = 5

demo()
print(x)
# Out:
# 5

# %% [markdown]
# Let’s break it down clearly 👇
#
# ***
#
# ## ✅ Your code
#
# ```python
# x = 10
#
# def demo():
#     x = 5
#     print(x)
#
# demo()
# print(x)
# ```
#
# ***
#
# ## 🔹 Key Concept: Variable Scope
#
# There are **two different `x` variables here**:
#
# 1. **Global variable** → `x = 10`
# 2. **Local variable inside function** → `x = 5`
#
# ***
#
# ## 🔹 Step-by-step execution
#
# ### ✅ 1. Global variable
#
# ```python
# x = 10
# ```
#
# * This `x` exists **outside** the function
# * Called **global scope**
#
# ***
#
# ### ✅ 2. Function definition
#
# ```python
# def demo():
#     x = 5
#     print(x)
# ```
#
# * Inside the function, a **new variable `x` is created**
# * This does **NOT affect the global `x`**
#
# ***
#
# ### ✅ 3. Function call
#
# ```python
# demo()
# ```
#
# * Inside function → `x = 5`
# * So it prints:
#
# ```
# 5
# ```
#
# ***
#
# ### ✅ 4. After function call
#
# ```python
# print(x)
# ```
#
# * This refers to **global `x`**
# * Which is still:
#
# ```
# 10
# ```
#
# ***
#
# ## ✅ Final Output
#
# ```
# 5
# 10
# ```
#
# ***
#
# ## 🧠 Important Concepts
#
# ### 🔸 Local Scope
#
# * Variables defined inside a function
# * Exist only while the function runs
#
# ### 🔸 Global Scope
#
# * Variables defined outside functions
# * Available everywhere (unless shadowed)
#
# ### 🔸 Variable Shadowing
#
# * The local `x` (5) **hides** the global `x` (10) inside the function
#
# ***
#
# ## 🚀 Extra (Very Important)
#
# If you wanted to modify the global `x`, you must use `global`:
#
# ```python
# x = 10
#
# def demo():
#     global x
#     x = 5
#
# demo()
# print(x)
# ```
#
# ✅ Output:
#
# ```
# 5
# ```
#
# ***
#
# ## 🔥 Summary
#
# * Inside function → Python uses **local variables first**
# * Global `x` remains unchanged unless explicitly modified
# * This is called **scope isolation**
#
# ***
#
# If you want, I can give you **real debugging scenarios (like why configs/scripts behave unexpectedly due to scope)** — very useful for interviews + automation scripts.

# %%
def rec():
    return rec()

rec()
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[9], line 4
#       1 def rec():
#       2     return rec()
# ----> 4 rec()
#
# Cell In[9], line 2, in rec()
#       1 def rec():
# ----> 2     return rec()
#
# Cell In[9], line 2, in rec()
#       1 def rec():
# ----> 2     return rec()
#
#     [... skipping similar frames: rec at line 2 (2975 times)]
#
# Cell In[9], line 2, in rec()
#       1 def rec():
# ----> 2     return rec()
#
# RecursionError: maximum recursion depth exceeded

# %%
def rec(n):
    if n == 0:        # base case
        return 0
    return n + rec(n-1)

print(rec(3))
# Out:
# 6

# %% [markdown]
# Let’s analyze your code 👇
#
# ***
#
# ## ✅ Your code
#
# ```python
# def rec():
#     return rec()
#
# rec()
# ```
#
# ***
#
# ## 🔹 What is happening?
#
# * This function **calls itself recursively**
# * There is **no stopping condition (base case)**
#
# ***
#
# ## 🔹 Step-by-step execution
#
# 1. `rec()` is called
# 2. Inside the function:
#    ```python
#    return rec()
#    ```
# 3. It calls `rec()` again
# 4. That new call again calls `rec()`
# 5. This keeps going **forever**
#
# ***
#
# ## 🔥 Problem: Infinite Recursion
#
# Since there is **no termination condition**, Python keeps creating new function calls **until memory is exhausted**
#
# ***
#
# ## ❌ Final Result
#
# Python throws an error:
#
# ```
# RecursionError: maximum recursion depth exceeded
# ```
#
# ***
#
# ## 🧠 Key Concept: Recursion must have a base case
#
# A recursive function should always have:
#
# 1. ✅ A **base case** → where it stops
# 2. ✅ A **recursive case** → where it calls itself
#
# ***
#
# ## ✅ Fixed Example
#
# ```python
# def rec(n):
#     if n == 0:        # base case
#         return 0
#     return n + rec(n-1)
#
# print(rec(3))
# ```
#
# ### Execution:
#
# ```
# rec(3) → 3 + rec(2)
# rec(2) → 2 + rec(1)
# rec(1) → 1 + rec(0)
# rec(0) → 0  ✅ stops
# ```
#
# ### Output:
#
# ```
# 6
# ```
#
# ***
#
# ## 🚀 Summary
#
# * Your function → **infinite recursion**
# * Missing → **base case**
# * Result → `RecursionError`
#
# ***
#
# If you want, I can show you **real recursion problems like factorial, Fibonacci, or tree traversal** (very important for interviews and ML/data structures).

# %%
def country(name="India"):
    print(name)

country()
country("Japan")
# Out:
# India
# Japan

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def greet():
    print("Hello, welcome to python!")

greet()
# Out:
# Hello, welcome to python!

# %%
def greet()
    print("Hello, welcome to python!")
greet()
# Out:
#   Cell In[6], line 1
#     def greet()
#                ^
# SyntaxError: expected ':'

# %%
def greet():
    print("Hello, welcome to python!")
greet
# Out:
# <function __main__.greet()>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def greet(name):
    print(f"Hello , {name}")

greet("Yaswanth")
greet("AUtomation")
# Out:
# Hello , Yaswanth
# Hello , AUtomation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def add(a,b):
    return a + b

result = add(8,19)
print(result)
# Out:
# 27

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def welcome(name="Guest"):
    print(f"Welcome, {name}")

welcome()
welcome("john")
# Out:
# Welcome, Guest
# Welcome, john

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def calculate(a,b):
    return a+b, a-b, a*b

sum_, diff, product = calculate(8,100)

print(sum_)
print(diff)
print(product)
# Out:
# 108
# -92
# 800

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def student(name, age):
    print(name, age)

student(name = "Yaswanth" , age =3758435)
student(age =34535, name = "Alam")
# Out:
# Yaswanth 3758435
# Alam 34535

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def total(*numbers):
    print(sum(numbers))

total(10,20)
total(10,20,30,40,353)
# Out:
# 30
# 453

# %%
def total(*number):
    print(sub(number))

total(10,50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 def total(*number):
#       2     print(sub(number))
#       3
# ----> 4 total(10,50)
#
# Cell In[15], line 2, in total(*number)
#       1 def total(*number):
# ----> 2     print(sub(number))
#
# NameError: name 'sub' is not defined

# %% [markdown]
#             SUB is not an inbuilt function so it fails work in above code.

# %%
def total(*number):
    print(max(number))

total(10, 20, 30)
# Out:
# 30

# %%
def total(*number):
    print(number)

total(10, 20, 30)
# Out:
# (10, 20, 30)

# %%
def total(*number):
    print(min(number))

total(10, 20, 30)
# Out:
# 10

# %%
def total(*number):
    print(len(number))

total(10, 20, 30)
# Out:
# 3

# %%
def total(*number):
    print(sorted(number))

total(50, 10, 30)
# Out:
# [10, 30, 50]

# %%
def total(*number):
    print(list(number))

total(10, 20, 30)
# Out:
# [10, 20, 30]

# %%
def analyze_interfaces(*bandwidths):
    print("Count:", len(bandwidths))
    print("Total:", sum(bandwidths))
    print("Highest:", max(bandwidths))
    print("Lowest:", min(bandwidths))
    print("Sorted:", sorted(bandwidths))

analyze_interfaces(100, 500, 300, 700)
# Out:
# Count: 4
# Total: 1600
# Highest: 700
# Lowest: 100
# Sorted: [100, 300, 500, 700]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def factorial(n):
    if n == 1:
        return 1
    
    return n * factorial(n-1)

print(factorial(5))
# Out:
# 120
