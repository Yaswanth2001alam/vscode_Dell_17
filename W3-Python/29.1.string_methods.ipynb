# %%
print("Hellosadwgr")
# Out:
# Hellosadwgr

# %% [markdown]
# Strings are everywhere in Python -
# file names, user input, APIs, data cleaning, logs.
#
# If you work with Python, these 10 string methods aren’t optional — they’re daily tools.
# You’ll use them for:
#  - cleaning extra spaces.
#  - checking file extensions.
#  - splitting and joining data.
#  - finding and counting characters.
#
# These methods help you write cleaner, shorter, and more readable code.
# If you ever forget the syntax, this one image is enough to refresh your memory.
#  📌 Save it — future you will thank you.
#
# ![image.png](attachment:image.png)

# %%
'hello'.upper()
# Out:
# 'HELLO'

# %%
'yaswanth'.upper()
# Out:
# 'YASWANTH'

# %%
'YASWANTHanth'.lower()
# Out:
# 'yaswanthanth'

# %%
'WORLD'.lower()
# Out:
# 'world'

# %% [markdown]
# strip() removes leading (start) and trailing (end) whitespace characters like:
#
# spaces " "
#
# tabs \t
#
# newlines \n

# %%
'yaswanth'.strip()
# Out:
# 'yaswanth'

# %%
'         yaswantg alam networking'.strip()
# Out:
# 'yaswantg alam networking'

# %%
'  yaswanth  '.strip()
# Out:
# 'yaswanth'

# %%
'I love python'.replace("python",'CODding')
# Out:
# 'I love CODding'

# %%
'I am network automation engineer'.replace("Engineer", "yaswanth")
# Out:
# 'I am network automation engineer'

# %%
'I am network automation engineer'.replace("engineer", "yaswanth")
# Out:
# 'I am network automation yaswanth'

# %%
'a,b,c'.split(',')
# Out:
# ['a', 'b', 'c']

# %%
'1,2,3,4,5,6,7,sdgyfs,yaswanth'.split(',')
# Out:
# ['1', '2', '3', '4', '5', '6', '7', 'sdgyfs', 'yaswanth']

# %%
'1,2,3,4,5,6,7,sdgyfs,yaswanth'.split('.')
# Out:
# ['1,2,3,4,5,6,7,sdgyfs,yaswanth']

# %%
'1,2,3,4,5,6,7,sdgyfs,yaswanth'.split('/')
# Out:
# ['1,2,3,4,5,6,7,sdgyfs,yaswanth']

# %%
'1,2,3,4,5,6,7,sdgyfs,yaswanth'.split(',')
# Out:
# ['1', '2', '3', '4', '5', '6', '7', 'sdgyfs', 'yaswanth']

# %%
'1,2,3,4,5,6,7,sdgyfs,yaswanth'.split('//')
# Out:
# ['1,2,3,4,5,6,7,sdgyfs,yaswanth']

# %%
'1,2,3,4,5'.split(',', 2)
# Out:
# ['1', '2', '3,4,5']

# %%
'1,2,,4'.split(',')
# Out:
# ['1', '2', '', '4']

# %%
[x.strip() for x in ' 1, 2, 3 , 4 '.split(',')]
# Out:
# ['1', '2', '3', '4']

# %%
list(map(int, '1,2,3,4'.split(',')))
# Out:
# [1, 2, 3, 4]

# %%
import re
re.split('[,;|]', '1,2;3|4')
# Out:
# ['1', '2', '3', '4']

# %%
'-'.join(['a','b','c'])
# Out:
# 'a-b-c'

# %%
'//'.join(['a','b','c'])
# Out:
# 'a//b//c'

# %%
'&'.join(['a','b','c'])
# Out:
# 'a&b&c'

# %%
'+'.join(['a','b','c'])
# Out:
# 'a+b+c'

# %%
'='.join(['a','b','c'])
# Out:
# 'a=b=c'

# %%
'%%'.join(['a','b','c'])
# Out:
# 'a%%b%%c'

# %%
'@@'.join(['a','b','c'])
# Out:
# 'a@@b@@c'

# %%
'!'.join(['a','b','c'])
# Out:
# 'a!b!c'

# %%
'hello'.startswith('he')
# Out:
# True

# %%
'yaswanth'.startswith('he')
# Out:
# False

# %%
'data.csv'.endswith('.csv')
# Out:
# True

# %%
'data.csv'.endswith('.csv1')
# Out:
# False

# %%
'yaswath.html'.endswith('.html')
# Out:
# True

# %%
'yaswath.html'.endswith('.html12345')
# Out:
# False

# %%
'banana'.find('na')
# Out:
# 2

# %%
'bana'.find('na')
# Out:
# 2

# %%
'yaswanth'.find('yasw')
# Out:
# 0

# %%
'yaswanth'.find('th')
# Out:
# 6

# %%
"apple".count("p")
# Out:
# 2

# %%
"applpppe".count("p")
# Out:
# 5

# %%
"yaswanthalam".count('a')
# Out:
# 4
