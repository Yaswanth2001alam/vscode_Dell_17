# %% [markdown]
# https://youtu.be/LffQVBq3P9o

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("Hello54515")
# Out:
# Hello54515

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
file = open("books.txt", "w")
file.write("The hunger Games \n")
file.write("The Great Gatsby\n")
file.write("The Maze Runn")
# Out:
# 13

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)

# %%
file = open("books_1.txt", "w")
file.write("The hunger Games \n")
file.write("The Great Gatsby\n")
file.write("The Maze Runn")
file.close()

# %% [markdown]
# In the below I am calling the twice again and again and will see wajht happens and what it does to the file when it executes.

# %% [markdown]
# When I run the same code multiple times it is not creating or doing anything to the existing file.

# %%
file = open("books_2.txt", "w")
file.write("The hunger Games \n")
file.write("The Great Gatsby\n")
file.write("The Maze Runn")
file.close()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
file = open("books_2.txt", "w")
file.write("The hunger Games \n")
file.write("The Great Gatsby\n")
1 / 0
file.write("The Maze Runn")
file.close()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[7], line 4
#       2 file.write("The hunger Games \n")
#       3 file.write("The Great Gatsby\n")
# ----> 4 1 / 0
#       5 file.write("The Maze Runn")
#       6 file.close()
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
file = open("books_3.txt", "w")
file.write("The hunger Games \n")
file.write("The Great Gatsby\n")
1 /  0
file.write("The Maze Runn")
file.close()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[11], line 4
#       2 file.write("The hunger Games \n")
#       3 file.write("The Great Gatsby\n")
# ----> 4 1 /  0
#       5 file.write("The Maze Runn")
#       6 file.close()
#
# ZeroDivisionError: division by zero

# %%
with open("books4.txt", "w") as file:
    file.write("The Hunger Games\n")
    file.write("The great Gats by \n")
    file.write("The maze runner by Yaswanth Alam \n")

# %% [markdown]
# Using the with open we do not need to close the code and the python automatically closes the file onces it completes it's intended operation

# %%
with open("books5.txt", "w") as file:
    file.write("The Hunger Games\n")
    file.write("The great Gats by \n")
    1 / 0
    file.write("The maze runner by Yaswanth Alam \n")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[13], line 4
#       2 file.write("The Hunger Games\n")
#       3 file.write("The great Gats by \n")
# ----> 4 1 / 0
#       5 file.write("The maze runner by Yaswanth Alam \n")
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ![image.png](attachment:image.png)
#
# books5 will be created and the code runs till the second line and then it throws an  error from execution.
#
# Just the last line will not run.  But we still see the ZeroDivisionError

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open("cisco_books.txt", "r") as input_file:
    with open("the_file_has_updated_data_to_cisco_books.txt", "w") as output_file:
        titles = input_file.read().split("\n")
        titles.sort()
        output_file.write("\n".join(titles))

# %%
with open("cisco_books_1.txt", "r") as input_file, open("This_is_the_nested_way_of_updating_data_cisco_books_1.txt", "w") as output_file:
    titles = input_file.read().split("\n")
    titles.sort()
    output_file.write("\n".join(titles))

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
