# %%
# !pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://packagefeedproxy.microsoft.io/pypi/simple/
# ...

# %%
# !python eve_ng_monitor.py
# Out:
# ^C

# %%
# !python eve_ng_monitor
# Out:
# python: can't open file 'c:\\Users\\v-yaalam\\Downloads\\vscode_Dell_17\\1.Python Learning\\Network Coding\\Eve-ng_down_monitor\\eve_ng_monitor': [Errno 2] No such file or directory

# %%
# !python eve_ng_pingtest.py
# Out:
# ...
# EVE-NG Ping Test
# ...
# Timestamp : 2026-08-27 23:01:35
# Target IP : 192.168.32.128
# Running ping test...
#
# Status: UP - Ping Successful
#
# Pinging 192.168.32.128 with 32 bytes of data:
# Reply from 192.168.32.128: bytes=32 time=3ms TTL=64
# Reply from 192.168.32.128: bytes=32 time=3ms TTL=64
# Reply from 192.168.32.128: bytes=32 time=2ms TTL=64
# Reply from 192.168.32.128: bytes=32 time=1ms TTL=64
#
# Ping statistics for 192.168.32.128:
#     Packets: Sent = 4, Received = 4, Lost = 0 (0% loss),
# Approximate round trip times in milli-seconds:
#     Minimum = 1ms, Maximum = 3ms, Average = 2ms
#
#
# Ping test completed.
# Result saved to: ping_results\EVE_NG_Ping_2026-08-27_23-01-35.txt

# %%
# !python eve_ng_pingtest.py
# Out:
# ...
# EVE-NG Ping Test
# ...
# Timestamp : 2026-08-27 23:01:59
# Target IP : 192.168.32.128
# Running ping test...
#
# Status: UP - Ping Successful
#
# Pinging 192.168.32.128 with 32 bytes of data:
# Reply from 192.168.32.128: bytes=32 time=3ms TTL=64
# Reply from 192.168.32.128: bytes=32 time=1ms TTL=64
# Reply from 192.168.32.128: bytes=32 time=3ms TTL=64
# Reply from 192.168.32.128: bytes=32 time=4ms TTL=64
#
# Ping statistics for 192.168.32.128:
#     Packets: Sent = 4, Received = 4, Lost = 0 (0% loss),
# Approximate round trip times in milli-seconds:
#     Minimum = 1ms, Maximum = 4ms, Average = 2ms
#
#
# Ping test completed.
# Result saved to: ping_results\EVE_NG_Ping_2026-08-27_23-01-59.txt

# %%
# !python eve_ng_pingtest.py
# Out:
# ...
# EVE-NG Ping Test
# ...
# Timestamp : 2026-08-29 23:22:32
# Target IP : 192.168.32.128
# Running ping test...
#
# Status: UP - Ping Successful
#
# Pinging 192.168.32.128 with 32 bytes of data:
# Reply from 192.168.32.128: bytes=32 time=2ms TTL=64
# Reply from 192.168.32.128: bytes=32 time=3ms TTL=64
# Reply from 192.168.32.128: bytes=32 time=2ms TTL=64
# Reply from 192.168.32.128: bytes=32 time=3ms TTL=64
#
# Ping statistics for 192.168.32.128:
#     Packets: Sent = 4, Received = 4, Lost = 0 (0% loss),
# Approximate round trip times in milli-seconds:
#     Minimum = 2ms, Maximum = 3ms, Average = 2ms
#
#
# Ping test completed.
# Result saved to: ping_results\EVE_NG_Ping_2026-08-29_23-22-32.txt
