# %%
print("Hello")
# Out:
# Hello

# %%
# !pip install pyvista
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install numpy
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install --upgrade pip
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------------------------------- ---- 1.6/1.8 MB 18.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 12.0 MB/s  0:00:00
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: To modify pip, please run the following command:
# d:\vscode\.venv\Scripts\python.exe -m pip install --upgrade pip

# %%
# !pip install --upgrade pip
# Out:
# ...
#   Using cached pip-26.0.1-py3-none-any.whl.metadata (4.7 kB)
# Using cached pip-26.0.1-py3-none-any.whl (1.8 MB)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: To modify pip, please run the following command:
# d:\vscode\.venv\Scripts\python.exe -m pip install --upgrade pip

# %%
# !pip install pyvista
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# https://www.linkedin.com/posts/pythonclcoding_satellite-above-hemisphere-earth-python-activity-7435230382171705344-_d71?utm_source=share&utm_medium=member_desktop&rcm=ACoAAC8IlrcBmvwrYuN0lmHmfRzYLS7LMrEqaGM
#
#
# ![image.png](attachment:image.png)

# %%
import pyvista as pv
import numpy as np

sphere = pv.Sphere(radius=1)

noise = np.random.rand(sphere.n_points)
sphere["elevation"] = noise
plotter = pv.Plotter
plotter.add_mesh(sphere, scalars="elevation", cmap="terrain")
plotter.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 9
#       7 sphere["elevation"] = noise
#       8 plotter = pv.Plotter
# ----> 9 plotter.add_mesh(sphere, scalars="elevation", cmap="terrain")
#      10 plotter.show()
#
# File d:\vscode\.venv\Lib\site-packages\pyvista\_deprecate_positional_args.py:243, in _deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     239             warn_external(msg, PyVistaDeprecationWarning)
#     241         warn_positional_args()
# --> 243 return f(*args, **kwargs)
#
# TypeError: BasePlotter.add_mesh() missing 1 required positional argument: 'mesh'

# %%
import pyvista as pv
import numpy as np
sphere = pv.Sphere(radius=1)
noise = np.random.rand(sphere.n_points)
sphere ["elevation"] = noise
plotter = pv.Plotter()
plotter.add_mesh(sphere, scalars="elevation",
cmap="terrain")
plotter.show()
# Out:
# C:\Users\alamy\AppData\Local\Temp\ipykernel_29884\2811682032.py:9: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   plotter.show()
# <PIL.Image.Image image mode=RGB size=1024x768>

# %% [markdown]
# https://youtu.be/kVKalJGngLE
#
#
# ![image.png](attachment:image.png)
